# %%
# !pip install torch
# !pip install torchvision
# !pip install Pillow==4.0.0
# !pip install -U -q PyDrive

# %%
import os
import cv2
import torch
import numpy as np
import pandas as pd
from PIL import Image
import torch.nn as nn
from zipfile import ZipFile
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset, DataLoader
from torch.utils.data.sampler import SubsetRandomSampler
import matplotlib.pyplot as plt
# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# %matplotlib inline

# %%
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
listed = drive.ListFile().GetList()
for file in listed:
    print('title {}, id {}'.format(file['title'], file['id']))
# Out:
# title unet_65(2).ipynb, id 1DWaLQuoDPDbcPPoRze5M5NSr5NOrXDvh
# title TGSUNet_epoch22.pt, id 150_ntQpNGlPdrwUXA7-cAlzN_CB1pjzX
# title submissions_near_thres1.csv, id 1PdcCQQopqUQ_1I_QFGBItFR8Yfur5-cY
# title submissions_near_thres.csv, id 1Wq4d6MrJz25ADrWpsHNZv_J0IDXy9HaN
# title TGSUNet_epoch12.pt, id 1eJe9ZJk1_aexLEnRBcOn1bhYUNPXSZBt
# title TGSUNet_epoch2.pt, id 1UK95HGCdUsFlGo51P5MEBZSWIXxdgWQB
# title TGSUNet_epoch2.pt, id 1yyzd9Oy8YizgdzLF72qcuKvhHzQKBQ9l
# title TGSUNet_epoch2.pt, id 12yFLU_JqA4WMbgVi3CpLP_yJIrlsQOVJ
# title submissions_unet2e10x.csv, id 1v-qNEUhy1VWoR_wzzfgPMh0UPu4tRqAY
# title submissions_unet2e10.csv, id 1ock3D-89NuPEW90vkICveP-cT7rC60aH
# title submissions_unet2e10.csv, id 1hjHgsUdb8CrmAC2hD8YDABJZjVJA-P9-
# title TGSUNet_epoch7.pt, id 1_12tBHbHScuTPsLt6pb5hOkTm8xEHd-Z
# title train _aug.zip, id 122ZmpdXDqWfEzY-zrLXSfyV3K8GTzZrt
# title TGSUNet_epoch2.pt, id 1gOhTyIJPair1rbrUouoQvKeG-KOCnNh3
# title TGSUNetsimple23.pt, id 1ICw_BD_PXGdKDs68rIpUXGtbDRPKaxL7
# title Copy of unet_65(2).ipynb, id 1QBXRsoSY9-r_oNLnYBkLAg08-8LdzJd0
# title submissionsimple22sigmoid.csv, id 1CRO9ZWJUtG2mFlOjPCmjL_wLfoz_mBw9
# title submissionsimple22sigmoid.csv, id 1GtFcLR8hGa8q2p8pOhMsqJFOR556beVT
# title TGSUNetsimple22.pt, id 1CzyQqU3ptQviLK2FvOHC4RmuJ2hWlRl8
# title unet_65.ipynb, id 1jZPJMjpGGrEkGIsk3AKJetNEpVBbT3dd
# title submission11.csv, id 1d1XFoSQdbsBdN2d8l3ZqCORVF_zJWb8j
# title TGSUNetModel61.pt, id 1BH5IJDJgHAEZW-YhpZhk8ivODC6hZL7I
# title submission_unet60.csv, id 1AakgGf955MQ4IXS6bnqlAWR-HDowofZe
# title testDataset.zip, id 1Gs1AlcVL9WNlgHQPSpNvbFtSbqNFZIdu
# title TGSUNetModel60.pt, id 19RV6bDJXWsx31YKPEkxQ_ZlCmB5pvjHc
# title processed.zip, id 11j1LyGLuq-HIHEgPNlzcxg0pO57rBA2y
# title unet.ipynb, id 1aJNZ1nVDzPe0j-b9zExz29Qet3ALktkG
# title TGSUNetModel.pt, id 1Q-84Ils87l7tmzI8gGeIw-EWSAbytCWF
# title test.zip, id 1LRGqfHQgvC3sbBkJY9lZ1jvptOieaQxk
# title unet.ipynb, id 1n3H6UegwRTqJ_XBgX_Bp_bx2WQld9LHJ
# title train.zip, id 1nJeSkGcVqeYD40rLyjlzCFBhFkmUmCSH
# title Copy of unet.ipynb, id 1Tv6iyOSxD_wMLRYx7sldhiV5V9OTMeL-
# title Copy of TGSSalt.ipynb, id 1jePVox0JDJumpGlCh1WbxCk9ce_DGlEH
# title Copy of train.zip, id 1QMSqw4n2stvX0xevj9r1g68fQo1mUew2
# title IMG_20180328_205506.jpg, id 1SFUq_0mfIkHGACtMDBx7DvDPiOZL1nrM
# title IMG_20180329_185245.jpg, id 1t7las9Gymc8BvYmFjRgn_6F6xjXvu0D4
# title North Kolkata Class Schedule, id 1yk7ky5KkQUe4av7IfPK4_8nlFsEYwcaC9gaxyB_aJnM
# title kaggle_loan_model_with_oversampling.ipynb, id 1HsZjWSxhTscEi6HHpyhGa-1g0KHJnDzz
# title home_credit.ipynb, id 10alOnjgNgjSiNWXACNdjlJfEBS9N9F3L
# title model_test.ipynb, id 1Wfax5YDQRquKD1L-Z0a0LkRHhsZUuM8R
# title Untitled, id 1X_E_O0q8K-9XZqWDtJ4N8bbdhoAamDCk
# title app_train_nlt60_cmt3_5_no_null_ef, id 1ffeOQb7yXJViZRkus0564jfFSihxNyqE
# title Eligible Candidates Yodlee(1).xlsx, id 16LYGulmjdBMY8xvHpVuhAV9ArPky7sp8
# title Eligible Candidates Yodlee, id 1ijSQTZSZPYzDpFBX-MfqF7_2Pvlc5ULlqd3IDakZakI
# title Eligible Candidates Yodlee.xlsx, id 1057C6cphqo5EvXSDnkVHdxbV-__oM3l1
# title preprocess_bureau_train.ipynb, id 1VxhnQ1Tux0FIwSnb1xs1i9iW_LeSBDu2
# title preprocess_bureau_train.ipynb, id 14wA2JOCTkE6KzMmL2Zn0CWE9ukwGINgT
# title train_all, id 1zIqgQuiHfpGKMWO6UUejLD0QDSMX8rCR
# title application_train.csv, id 1MjUvAjQewf8s1jG2BYmRPA4QErL1M9b1
# title application_train (1).csv, id 1s25Hj_PRLNrOVT7F5c8ZghqNQmIcq7QM
# title application_train.csv, id 1ZWYb_GIkK7wWU-kVJKJKat4yXAETVAvI
# title Colab Notebooks, id 12u614Bgf9Iox9NHwLuNp-WpvcUrOJclI
# title build.js.map, id 1DU7iXm1n5orDhbjOWgHSNZUgEeQMErKU
# title build.js, id 1AGrtgvQVXrQ3g8bxNLed5-l8F2mDO-yr
# title au_bon, id 1y4zSjFKcWPb7-9wabmR9dvdZdtV37_Fx
# title au_ban.zip, id 1DZJFdVQbQmLso6zGhJY0ZtTvRrF0GOYD
# title htdocs.zip, id 1tvfEzy_N5Vh29GpKt7T7zQ6RRtXAlm9a
# title Blockchain.pptx, id 1eQAW52soCWr-48klVxtF05zO0geFM3ML
# title vegetaSu.ipynb, id 1ZsBMT_aDzYXQ9eDfDCGLOq4YsejOs7RC
# title Untitled spreadsheet, id 16bTWnFFpmr_zXsAdXKtbROIL6f1QQkFqmohYWFiTot4
# title piccolo.ipynb, id 1_-8GMNvxlIWjfNZ4Q8Id3Pvu7zhQgbVK
# title Copy of word_embeddings_train01.csv, id 1BtWnU4Fk_a6CmC6LuQU6eN336al8Uijh
# title word_embeddings_train01.csv, id 1B7ciYrN_OTFdyIUHN1WdDBayBTN1Ifw-
# title Untitled presentation, id 1fqzPpUrurqrdSSeyxZO1Y0sMKrYVaR1ljVK96WuDHfU
# title IMG_20180331_030014_HDR.jpg, id 12yYGwq7SQ5mxle0RG6bWwFxgw3yd6Bun
# title VID_20180401_195211.mp4, id 1dclB3t25c6iEtPpHLZUeyxPfVxnLgedl
# title IMG_20180401_192227_HHT.jpg, id 1l5LXmiV4_K8R3I3LeTmDxzbe5Uv2SJAX
# title IMG_20180401_192234_HHT.jpg, id 18q_HUL8CI7NsOkDkuBiRLJurCEviwAe1
# title IMG_20180401_201906_HHT.jpg, id 15wC0KbY_QCtMqFXe01zFbXSlGPZiJXwc
# title IMG_20180401_201853_HHT.jpg, id 16rX2YrJH62Ze7fUnSbs-n_iKS4aXp8mq
# title IMG_20180401_192232_HHT.jpg, id 1iAaDHhg1Jjnxrm7Wooaqb4gdEHZ_-uLe
# title SIH-18, id 1onG4IcjTnpcooRsdWaJJJEyZ4wXCuWtT-JP_9rXNpfI
# title IMG_20180331_032344.jpg, id 1hAsLwB3tliZwAHJFMEDVPzzhkkKGOGB0
# title IMG_20180331_040445.jpg, id 1YFQooNPR2fRLrfQ4l3eno4Nb1iMXes8g
# title IMG_20180331_040424.jpg, id 138ZlbauFRDhV9sYxgzOFh-xcP5Zt8TTE
# title IMG_20180401_193933.jpg, id 1oKH8738Qh0BV5MZGfjUDf-0uGccjGrzH
# title IMG_20180401_193215.jpg, id 12lUIhHzn9HkXln33gmKah3nsrF9dCPp2
# title IMG_20180331_032748.jpg, id 1m_ZCVvhjUfLAVqNuDFXd_3z542unKr88
# title IMG_20180331_040446.jpg, id 1_xB2iTvYWqZdaNvJrGJ7sFXHgJCY-tba
# title IMG_20180401_195441_HDR.jpg, id 18488zg4OnYx6m0TNU47_WS6G3IEG9KsZ
# title IMG_20180331_032443.jpg, id 1jBAbZlVfYY2eZF7exZVNbwAw7rCOfV74
# title IMG_20180331_040434.jpg, id 1cJ4TVKyk1MAocBoPwOxCawbPbJs7rjG9
# title IMG_20180331_040438.jpg, id 1zKF6h7ymCzuCpcfljgAp_fV6kG-yO8rj
# title IMG_20180331_032631.jpg, id 1fRkB1y4EktNn9XRHscdCDtNwdLieOwDU
# title IMG_20180401_193519.jpg, id 10Nd5ZbFOXqlRBtoVapXkaYZEHxyqpufl
# title IMG_20180331_040443.jpg, id 1Z8fuFLbaiYsQJfV3LD1Wndq-j69hwD5O
# title IMG_20180401_193827.jpg, id 1QNqKypjhTW1oi-NhyBt-SQ9UwgFfWl_j
# title IMG_20180331_040441.jpg, id 1zFQ3S0VtYLQODfZw4VbLJXpR05y418tH
# title IMG_20180401_193853.jpg, id 14oevWkE0i_XOso9TtSKI8Sp79UqLNcf3
# title IMG_20180331_040442.jpg, id 1MbUflbmUOkggaYrIQreglZT3KIw6vwlr
# title IMG_20180331_032545.jpg, id 1Iztpeg_vYCu2Ek8NUp-drbpR6HxDqHz2
# title IMG_20180329_183331.jpg, id 1IZ_Atg5d8MFmdFOElFUFhGPGNXYLh79J
# title IMG_20180331_040444.jpg, id 1sU_V_L8buiK-hLMvEhiN3agyoXYx8xfh
# title IMG_20180401_193500.jpg, id 1JJuwKmCJnLWJIMe2GOSiDazvWDJJt9Rq
# title IMG_20180331_032439.jpg, id 1aYHkGlwq3UUZY12Kc2oMEu6zwA66F3Pg
# title IMG_20180331_040422.jpg, id 1XFtzFrQN78Uen5byyu5raMiZp4fjwdXK
# title IMG_20180331_214958.jpg, id 1bWYrWiHZe55v40nMClI-bS0YClq5q8SV
# title IMG_20180331_040432.jpg, id 1aTdOfH0Ou2yo7TocrZOnxa403FasnT_c
# title IMG_20180331_040447.jpg, id 10JGiNvTDWY6Na_wcrbY39isP3nAfeQWS
# title IMG_20180331_032653.jpg, id 1LXLcGSk_2gnCfPUhE8QaD79SnfMk08ax
# title IMG_20180331_223419.jpg, id 1l5Ai21HlZNWDLBeAhazV4uVoHSUkguYm
# title IMG_20180331_040430.jpg, id 1KK3p68IfpBgYgq3IfbI8acuLm_yf7vfj
# title IMG_20180331_215000.jpg, id 1KBYN8jU_18XJ4NJkX8zR6yazaEpOVeaE
# title IMG_20180331_040433.jpg, id 1u2ZhgBX7x-5k2wvrI-IQdk0w_7a6jj-a
# title IMG_20180331_032454.jpg, id 1LaGc02hk4w1lhHMs-PtB23O-TIMzdmm-
# title IMG_20180331_215001.jpg, id 1S4EAhkCCWiJiSxR7rlVHf7B7e0XlGa4a
# title IMG_20180401_190741.jpg, id 1py3Aff4wXjSQRVLMgdJ929Gn0RUPPTar
# title Sumit, id 1mzirnp_Rw4VoG0FAROLN5A9tQdwyBkWO
# title IMG_20180401_203931.jpg, id 1pWUjERTLjmjPUZ-s18yIr22wD6vj1UcK
# title IMG_20180401_203927.jpg, id 1BTWg4raoBSRATcu6xquqMFpgnBCc1IBH
# title images 2, id 1qmv0aZ4wHFlqZ24vErCuWxSFr8uaDx20
# title IMG_20180328_205402.jpg, id 1706_r6eR0KwUABvBgQIRcuUE5rSpfWLB
# title IMG_20180329_132158.jpg, id 1k1EWhGNOvptmtvpzGcs-wj6yEuA2Ii81
# title IMG_20180328_205412.jpg, id 1orcu16MqHHXiEQXNcpxuuru-ENHC5n0k
# title IMG_20180329_215401.jpg, id 1toOT1MkPAqvn25cF-ObHteHPKFRuxncc
# title IMG_20180329_215405.jpg, id 1D6uwYBt_jv3rRpVb_6McijRlRPF8yiOV
# title IMG_20180329_215426.jpg, id 1KjR5RioGOm8QE5lL_1bbe6ZijqANyzbP
# title IMG_20180329_215441.jpg, id 1BybHwhhSdvC05X0PiwgFS-m3xMvQBzO3
# title IMG_20180329_215428.jpg, id 1uuHtb21UexS1ryACMKGVyhMWwcr6C-Yo
# title IMG_20180329_215507.jpg, id 1yqQ4phtpdTtfabgIzCHxNSoATV4tblOE
# title IMG_20180401_202931.jpg, id 1TIX0jR0hUFVTIBnHyKt-myl7umkTK2wJ
# title IMG_20180401_193725.jpg, id 1vOFyW3hBLiDIAXXaYsIZMEeqb8PYoLjO
# title IMG-20180329-WA0009.jpg, id 1U_zmvioUZ0j0ENStN0xu62UQylImOzw8
# title IMG-20180329-WA0007.jpg, id 1cYPVbxLJ6WjgYZZC8XEpdrKN8vVzhzfZ
# title IMG_20180329_132259.jpg, id 1YLB_-J_QBESJ6AUbKktOPpFBAsKeb2qy
# title IMG_20180401_192044_HHT.jpg, id 1vKpO-VW-NuOjwHp3NG29yMJp3mvMmtnF
# title IMG_20180401_193545.jpg, id 1AeLS5Z5K4VFTR2z3hY5OGgFo6HY2pR_k
# title IMG_20180401_193726.jpg, id 1OFz1GwDOz4ZpRpaPzNW2vBcJswVA3PM4
# title IMG_20180401_191518.jpg, id 1QUYhM1KGTJuxe5Dko8vSxxHTMW5uZmek
# title IMG_20180401_193251_HHT.jpg, id 1stIcbhgI3JlKbPgyrnjEEBDsQplYZXaA
# title IMG_20180401_185108.jpg, id 15BiJnUf5mtQb0_uq-XyAF3jk-zbM30dr
# title IMG_20180401_193728.jpg, id 1cFme66KoEHTH4dt1RsK3jOvAfNJ-kYXg
# title IMG-20180329-WA0006.jpg, id 1LqG2c4YDOk8m50rMV5pG57QKxTZagy3Q
# title IMG_20180330_200140.jpg, id 1Ia26_ZZu6Snyk8WITbNceoU-4VfrC0qG
# title IMG-20180329-WA0008.jpg, id 1yTe3H8oish9NppHfEMZWDUmb6PD3Seqk
# title IMG_20180401_193243_HHT.jpg, id 1sMVuTXjQEfr60tDKf2r56kxnVcKSapZS
# title IMG_20180401_191643.jpg, id 1x1jW4sv6-PzbSUGyYUW6w6vzrrFUr5O4
# title VID-20180329-WA0004.mp4, id 1mvaE_r0DMfjK4GISmwk-zJGoVQ5Jsy0h
# title IMG_20180401_193723.jpg, id 1oRwF7BB5VMbmzKfTgbWLJ2AWavsGl2cB
# title IMG_20180330_200144.jpg, id 1FPuVdd7Y9-ZidgHaDbV_71faeYSTc0hk
# title IMG-20180329-WA0003.jpg, id 1iJU4BnxqZrMsCgfzu9YixNdkrQ9HODYC
# title IMG_20180330_200050.jpg, id 1ZkHOBDdRCzH_tOHSWxNJye1DYjUBRT4f
# title IMG_20180330_200114.jpg, id 1YYfl60vw2JSJv8iTOYGZI-gqYyR6Nkuc
# title Images, id 1_F0rH1LcFeKVwmsJpRT8Zt-cDZ35Npex
# title SIH 2018, id 1kmmEMeNj5mRomvJvaTbixNydmWGh3VRg
# title app-debug.apk, id 1CuF_WfZe0hcpjfLc9S-kzP7kYUakTPpf
# title MaraChange, id 1DTUB3itvlDkZ7uAXZ8Z8LD4-CeyicNt4
# title shimla manali, id 1w0Tumo238b4-cUP9BFuG0vODd1wR15su
# title SphereGenerator.html, id 1o2Ll7Qloftu2wwPUfrIIAf6XxD5-dP9i
# title Segment.html, id 1j-yarAyrw7PW30aR5qZN-LrIVx7-vB-u
# title SphericalCoordinates.html, id 17hAIj2qWD3pv5lvuYi_iM7NIzElfXF-k
# title Vector3DFormat.html, id 1ZvHZ4SUJB8Un_E9J9b4zLf-AlutZwIGs
# title Vector3D.html, id 1vvEWD2B30Zwuy0nImwirdaOtCjhVOYRP
# title Rotation.html, id 1xtrOD8R6zsSuS7Ii41ibP5tgh0edJU2p
# title RotationOrder.html, id 1Zb31uAVzHtmK8GCENFRD4OfTHBR1E_Hh
# title RotationConvention.html, id 1PPvlmkAGH8dmMIRI8NXe1zxpUsQ2NF7E
# title SubLine.html, id 1AlsE870VMziSuRGRZMf4iI5LwqKGUnVC
# title SubPlane.html, id 1AD3CnpM37l6pOYG_oL8WdzcJgQf4bmVb
# title PolyhedronsSet.html, id 174oGUOZF2FU3HezSnBfiNwtlzPzx7UAH
# title Plane.html, id 1TWSTex_f4BAxqTcaLRS23ZwNTvQoYMo1
# title OutlineExtractor.html, id 1J14iI_Cx3wt_GhqZpl7LOB2jWiWW8-G4
# title NotARotationMatrixException.html, id 1lH2mC8a5M5k8UgmL1eMjUtTUKbGmGb2i
# title Line.html, id 1sFSTL_6-scrz3Qsz3kUCao9j6ERclb76
# title FieldVector3D.html, id 19a_m0BPSeNXVAU-zpej9xZLoAqfdeAD9
# title FieldRotation.html, id 1ZEeHGRZaWY6jNscQULt7C6SxsMbrwn_3
# title GaussNewtonOptimizer.html, id 1Drp03Aof9JivQOfyDp6bvJl_53jNXNjq
# title NonLinearConjugateGradientOptimizer.BracketingStep.html, id 1ynaiWopuHn5Ey3NNXYZl9FRA_EDk3siU
# title NonLinearConjugateGradientOptimizer.html, id 1hR52noEeZbFJDtYpH4pv6rSAMdC7V7DN
# title NonLinearConjugateGradientOptimizer.IdentityPreconditioner.html, id 1-7dedYPTFSNKhkJ7YdWDIJSlRviJbt7p
# title LevenbergMarquardtOptimizer.html, id 1Luyxto0KV7g5rmel_yboHrzSxq_ljsA0
# title NonLinearConjugateGradientOptimizer.Formula.html, id 1NiukAeOhBCoxBINhHCzt1LrsgeuUicLy
# title Euclidean3D.html, id 1ENvAM-RGBMQx15qY5iSvzvgB2BO2J7wG
# title AbstractLeastSquaresOptimizer.html, id 1J-7tfMKF0vGsAbt8mIFxqmqFTS1ITHQN
# title Preconditioner.html, id 1pyWWS3fUBkIMEDfEbNmYH6GcXZIggPlb
# title CardanEulerSingularityException.html, id 1p4U8lXo7_cy2vuemWlkRBekvIxj5bhuP
# title UnifiedDistanceMatrix.html, id 1wVlo1i0z3gU_hjE94dSGVlwsbqYPXZ_-
# title TopographicErrorHistogram.html, id 1sTWJ4ZHj75lmGt65J_GUbFFGeEAKI7yX
# title SmoothedDataHistogram.html, id 1Zf1RJJ1JHISI3lth7J0AABMofX-QRPPH
# title QuantizationError.html, id 1olP9g6HoHZnR1zg781YocuWnPtMNHBju
# title MapVisualization.html, id 1W51HtnPlzJ4IYd3GORN648BB7NdYOifp
# title MapDataVisualization.html, id 1-JS0tlbXmWaRQnuIcv-N2VirhBYLVz1s
# title LocationFinder.Location.html, id 1ZumYijUEMb-qQoozeUunYHMaFvXsxRg1
# title SimplexOptimizer.html, id 181kO1HDVwjHaVk5ZT4l2nZz1oy2krOtN
# title ExponentialDecayFunction.html, id 1WsmdHYTMYT4eKTRbo-e8Tj-ez_hWejuF
# title ConvexHull2D.html, id 1Ngmht9reLnTooRmdS0gw1IzNanTzPHP7
# title ConvexHullGenerator2D.html, id 1Z21ko17hjUJRDzfsnEtsjERTnP8ZMSFN
# title QuasiSigmoidDecayFunction.html, id 19TsMOjB05F2ga3EhD4Mi_bYcwaDbOld_
# title AklToussaintHeuristic.html, id 1cWdMW3_aMAhISPm3suZFLOqnmg4Gy6Y6
# title LocationFinder.html, id 1oMlhaBZD837MG4ynIdrmLQWW9AMUf7el
# title HitHistogram.html, id 1uPaXjA5kyx0e9YC6m5VfffuZUr6WKQvO
# title MonotoneChain.html, id 1T18GeZs1-CkVFwgRNxbepCzV8ezqmZ_o
# title PowellOptimizer.html, id 1aLUV7e9osuiiDbsmuez1hYVOAzUWnYkU
# title NelderMeadSimplex.html, id 10ZbOMRLe2Fd82m4ArzVZEFSHW_pdivb4
# title MultiDirectionalSimplex.html, id 1kmTpdon8hA9-Ix9ULRDKMvzPbmzIkAHP
# title CMAESOptimizer.Sigma.html, id 1Lw67AAQ-XSrSj-NlA9J0X3h_rN4CaUZw
# title OrientedPoint.html, id 1QcybpyHefBYDr1MfrgDDjQrgLVy-TZe8
# title CMAESOptimizer.PopulationSize.html, id 1ZgyVjMFesgD1cEuOYSnyfUlpHblBaa4D
# title CMAESOptimizer.html, id 1Mt0Qv51nvhkLyGoJC149oYp2t8iMjRIq
# title BOBYQAOptimizer.html, id 17j5s_Y_Kw-Scl8MacJaV-fJHFzHtvg32
# title AbstractSimplex.html, id 1xRpDykEWXLjV3cT-Iww4s3an4C50md6-
# title Vector1DFormat.html, id 1Urwd3XvamcpAP2rUEQZ-3O4bO3EM5qKY
# title Euclidean1D.NoSubSpaceException.html, id 1E3TlOfuTnjsCv4v1xwzwzB1M5gnGWELp
# title Vertex.html, id 17jkH3RX6fPjDWjG7_jjPmaf-3t8OI-Oz
# title Euclidean1D.html, id 1g8IkVilXO---R6QCxK8jr3YI0U4pKksc
# title Interval.html, id 1bRjzoPDgK79NG8chgAJU99KYDD1lG5jc
# title IntervalsSet.html, id 1VuPjVMXuQbKIs3j67rGx6DPCz3zgMv_V
# title Vector1D.html, id 1ON2miM5coWRglLKjC-fMMHTkHCnUYKbR
# title SubOrientedPoint.html, id 1wYY2c42lL2nVr8xumDJMR-hq4a4d0dYO
# title SubCircle.html, id 1qrT6EWKeA8uzeVqNqZMVC6zh17pMqFC6
# title SphericalPolygonsSet.html, id 1wcWx-WSDnzWkyJn4DUkvzDuqjSAX_2iC
# title Sphere2D.html, id 17ywPeXiFB3SED4F-0uyou5CPI_yYXgDs
# title S2Point.html, id 11tkc_vD-SW-vyUIdfvTYs4hxPwl_cFCw
# title Sphere1D.NoSubSpaceException.html, id 1yxRrXLCkkwDc1NbKATCYB3PhX7eO9jK_
# title Edge.html, id 1w3nbNxLdOob-SSYZ7K01HsJEryeXS-ZA
# title Circle.html, id 1x269nhhow4UvO6zcqAQ2lq1M5MGPckvQ
# title OrderedTuple.png, id 13oCzV-Oqx2QE0EwZsv5KWU1lWz6JI7hS
# title OrderedTuple.html, id 1CfeSoYiIpxW__yrRAfRDm9qQ1_pp02tL
# title AVLTree.Node.html, id 1DLvB27ejQalLpqe29MiIMlVajwwR9irH
# title ArcsSet.Split.html, id 13zlND1i7wtgx9dP_MjY1MMsOZOIxMw4H
# title ArcsSet.InconsistentStateAt2PiWrapping.html, id 1lR8A_Kf63iXFrurO8qI2hu1R4B3GFayH
# title S1Point.html, id 1LHBSssGO4O7sXqhG2Mngw_AaYi8Af756
# title Sphere1D.html, id 1YNvRiuLgozCGoXopHdnKFNuLpeuhmEfi
# title LimitAngle.html, id 1FjI8fk-jJA-bZ9Yl6sV8BOmGIM6UvfBp
# title SubLimitAngle.html, id 1_IyI9xgkQLDrmAMW1CDn5Gzu9RCtPgVr
# title AVLTree.html, id 1TolZo-jxYBPVKyJjJfcug_TEKsB5y8Ec
# title ArcsSet.html, id 1Sd_riE0WPkrGgIo3HtGavYexfuO-Kgrd
# title Arc.html, id 1ZzR2wOeLIaXDM9MZf4PgrwX0MZa06Ew5
# title package-use.html, id 1I3-GXsImz0tTneGKKQ5b0Sj4VaMATqik
# title package-tree.html, id 1RPP2FAFj-Uftx_GxlizuQFYV8ngfRCif
# title package-summary.html, id 1wlyWfXxjR0by9dg8zRJ6bqhshVnvNchI
# title package-frame.html, id 14Kcv5LshcvRW1Gj-Wm8fW4FG7KCaVfwY
# title MonotoneChain.html, id 1yNbVFUWsO_lPRqZP2O0i2kfIRxiMl5LA
# title ConvexHull2D.html, id 1Ze6PrnRaZwkbHXAir1fo92YIdKMexvWu
# title ConvexHullGenerator2D.html, id 1_xTOesM9rKybKx-8XSt_vaugqrSL_t_E
# title AklToussaintHeuristic.html, id 1us-vvE8D6O7gQPCvqPoNUy_PRewmFbbG
# title Segment.html, id 1sRwyuXj13BTtszx0WukWoueAD9s43MxO
# title PolygonsSet.html, id 1zrRqmefqM6-HYQ_rEeLPFubetIeFkk_i
# title Vector2DFormat.html, id 1QrnW8nNavyd-DWX-Jv90dwhSHKgmJQrD
# title SubLine.html, id 1Wqh0Uc7tKnElUwG82EiCPsbGLZgJlFwL
# title Vector2D.html, id 1TyRZRMw22l2Ln8HMUumj4dCSxQnSiRel
# title Line.html, id 1VW7xGyK6aZ7lYSGSEo-4lDMU_wb07fit
# title Euclidean2D.html, id 1ZmoRTNY8k9NDgObHsRix0_iCYahjqdFf
# title DiskGenerator.html, id 1KUQVnLOw9YBALRncqa_yRoL52yhWp5FU
# title SumOfLogs.html, id 1Yu0Nb-NO10Mej347gvyz-wtqI5f9fK8w
# title SumOfSquares.html, id 1OB_ihRfApKas7eegaz2BpLgmuNqasdwq
# title Sum.html, id 18UJ2H8DcA1lRvPbzJUpK1keBMBF4ZtNs
# title Product.html, id 1bVX6vSl174cSpfmT3IZpdWnX5oyZ12-S
# title ExponentialDecayFunction.html, id 1rDJosyDYtr3FQju3dskwJ3KMD8i7iBt8
# title package-use.html, id 1ahuMSBYvZHQulWfix01mCBCLEp5P24om
# title package-summary.html, id 1uOM8cy5iLasViNxLXDg7v_gavI0o0FYZ
# title package-tree.html, id 1DXtY_8aRokP8FJXohd25ozCsMx8y3TEG
# title package-frame.html, id 1dUeNQP4HuD7GlJrVCf9mSI9IKqq5AF6v
# title QuasiSigmoidDecayFunction.html, id 1O2ghbgmoqEtpFRwU0oKr5qC6pY_FDlqW
# title NeuronSquareMesh2D.VerticalDirection.html, id 1UpNcDbnkv1_dRlsL-rRUjF5ivsTPcffC
# title NeuronSquareMesh2D.html, id 1Y3MPCTDuMH1zovMo8MZeB9NkQCTTNjJt
# title NeuronSquareMesh2D.HorizontalDirection.html, id 1pt7NW0nMkgNZABKKlv5rXoo6JWcNkjfu
# title WelzlEncloser.html, id 1pkkV3zQNunalFH4Z6snRHglZ3Lk2aNLu
# title EnclosingBall.html, id 1jUvrAcHqnJUQc0pFGrqOzGF-4ruuRnnE
# title SupportBallGenerator.html, id 1SI7sP2K9eo1e_7AXH4LzP4mmLI5fPswp
# title Encloser.html, id 1Yc27g81AMBZyGv4elV7kI-gYH2XzZ0lR
# title UpdatingMultipleLinearRegression.html, id 1mmACpTjG--ZvobKiGbmdUB0MQeZyRvFv
# title AbstractMultipleLinearRegression.html, id 1yy8OFBNG-uUy4aWMPq74Mv7pQITvBxDp
# title PSquarePercentile.PSquareMarkers.html, id 1GcS3aLx0UH8zmoQEKj2mF4G0RQ4bPcY3
# title SimpleRegression.html, id 18aWL8oA1_hdnwYyTGYWO3VaKkeW6bhO6
# title RegressionResults.html, id 1bJnbnawzOEl7AuVkCh3m754rxejvhDsK
# title OLSMultipleLinearRegression.html, id 1JFDg5XzbYiLHtOH1aoVv15CxXMOCo3Z3
# title MultipleLinearRegression.html, id 10H7ahQa6lS9PWzFKpSOQIKHGMh9mXutn
# title Percentile.html, id 119eKhEgqRFbddQ-WtGdV2OAFzjOtjJu1
# title Percentile.EstimationType.html, id 1a8bTGzstkiNof4Zfampc6___29JxKmOL
# title Min.html, id 1r0iTDjwNiovvMdkMWQKWvAcopAJRPTEA
# title PSquarePercentile.html, id 11TLDgf3WYgSzPR5ptBcl0QDITmNktzaE
# title ModelSpecificationException.html, id 1kt5OFGlvJSoX9NtymocKaW4bz91_ulbI
# title MillerUpdatingRegression.html, id 1kaZJWIFIO1TOgFFL7i3FDFNwXXepdcID
# title GLSMultipleLinearRegression.html, id 1sgjpMoX9tSTkNk3v9yXNRHvPBwLiP6wX
# title Median.html, id 1qNk6j9-JdiSmjBvy_v5bzTniVHn3NAPA
# title Max.html, id 1j03wOgwRFzcnBDL7Oj5YNuf7g8WX1-IW
# title NeuronString.html, id 1wfzDAB1F_rk1PZvpoxWReHF-EwcqgA6R
# title SumOfClusterVariances.html, id 1Vzk2mQdqI9q26NxBWSsSU6DMMTj8CaJq
# title ClusterEvaluator.html, id 1o0B1bsFtbVV73I01u_rmLQiZ0cn8ck5Y
# title VectorialMean.html, id 1f4gNLmCskVxk6vYC8cxSaBFXCgawagso
# title SemiVariance.html, id 1GKSrLQS-J9DylO0pOLxuJqMzTin6ePRL
# title SemiVariance.Direction.html, id 1kuhnwkhGI8QkzNGFnzgKNHbbXT0s3GLs
# title Mean.html, id 1EVbSjG1KsVIbs-zzc4D62Y2PPIzgw5YW
# title Skewness.html, id 1jyColsXNSVlgUNYqYm5aKoGAUu_y7uyP
# title SecondMoment.html, id 138i4vh5XKu3rHc1lyqkTAfS6-JGVCx4s
# title Kurtosis.html, id 1wyw2gu-aFcNddVM8aT3ZZn6KbuPhv5ET
# title VectorialCovariance.html, id 1D5c7S2jXJAXR2gDzYK5sOwxM9Jrv8gg0
# title Variance.html, id 1va1hQEnvhkPsb_jnMpTh97Efyorhkf2j
# title StandardDeviation.html, id 1H5ZjGZM-Fd9O9tG_5hJBo8POVB_-nlIC
# title GeometricMean.html, id 1YYj8oNJfZpUekXsuDNyblYcED40COCtZ
# title UnifiedDistanceMatrix.html, id 1pTZqLVPqpgnToUe6ykdHAkHR1_9ypnN3
# title TopographicErrorHistogram.html, id 1DGX3RimTfptEVrZEFmr5QCqnzXFS6JeP
# title SmoothedDataHistogram.html, id 10C8tmCedlozBv4scE8sDKx7TOGFG9Npt
# title QuantizationError.html, id 16AV0TQLSMwJ5CaamlUseMBmdpbT3H8WJ
# title package-tree.html, id 1vJfz4GIGgWGEANFJfrzNg8T5O4tOxScO
# title package-use.html, id 1fTSEetWCTrLB55eLd5QfRv4TJxmj4fYn
# title NeighbourhoodSizeFunctionFactory.html, id 1OlAjrRQQpUTE0gE-LmbvZ9JF3fZgoXOA
# title LocationFinder.Location.html, id 10r4UrkQ3AMZAYw8n4rlXvhb5h_nNWwry
# title MapDataVisualization.html, id 1Vknt2VpbYDSdcWvZc_KmETKxlLpV8MEZ
# title NeighbourhoodSizeFunction.html, id 16Qkqoo8urACD5Y3k-UmEJ0MZOcss5onH
# title LocationFinder.html, id 1SVCE-7-T495qjfuSImn3lmKeqdsqmMVj
# title HitHistogram.html, id 1ot11QFLSOb_X1gBzFkiMQd5kr-Ncmc1P
# title package-summary.html, id 131InMQQ_y2kUlIJp0BIT5FP7t42kX8DI
# title package-frame.html, id 1WnM2pD1MBY_gcur2DUKn69JZR5kyIWpu
# title MapVisualization.html, id 1LuC66f02TzcVtjGuRl1qkM2qy4L2png4
# title LearningFactorFunctionFactory.html, id 17f5sigIv17M_a1b_6f24z8jzuzO2rIQ7
# title KohonenUpdateAction.html, id 1DoOIzKdnKtuEIZ_paRmV2x-dMSmv58mz
# title LearningFactorFunction.html, id 1t3Gz5xiG0vEbMDPTIhB1LhecLPPf936q
# title KohonenTrainingTask.html, id 1CKvS_j9969NmemrJZRM1xQHJOvTqQa2z
# title package-use.html, id 1Ca8Jn84oWAeeL7Dd1bzKLF2z9vSprdZK
# title package-tree.html, id 1a1Tlj-1bf9AMhp0VKeAt2DnAYH_G2POj
# title package-summary.html, id 1OIj_hj-YBP-yVy3BV-kuhBBzP-uoEKyk
# title Target.html, id 1o2OfvW1lfVVw34ux2-vkTsYaTGl1_Z2J
# title GaussNewtonOptimizer.html, id 16w2gY65sJxm_Cp93uTeZ2d9yNXTltG_H
# title AbstractLeastSquaresOptimizer.html, id 1VTwSU30BzIy9yyxsLuDUJlEO-VaXkw6E
# title MultiStartMultivariateVectorOptimizer.html, id 1H7fOClhWED1pZO0VRwlhnjZZj3q1YxI0
# title MultivariateVectorOptimizer.html, id 1vOtSzJkXg27xZ7q85hUdgM4wLzAuISNH
# title Weight.html, id 1BcQgzxleIlpgNYyG-mz4tNQBG7GiW_t6
# title package-frame.html, id 1Z5mW8i19lHaoo8d5cf8EfFDJCwcnCt0s
# title LevenbergMarquardtOptimizer.html, id 1dvAxNukhWb3Pu40_AP_89S_fbEcfhWi2
# title ModelFunctionJacobian.html, id 1NPbw0EsamhjvY6-6gAxfS2gP-khtRGaz
# title SimplexOptimizer.html, id 17onKfI-SSMdlbG_KSBkrDF-l1zlpxGSU
# title JacobianMultivariateVectorOptimizer.html, id 1_WnuZ3KnMb7i2C9H1JKpcZVApKZ-2v60
# title ModelFunction.html, id 1RGyovCKlumamnFtT1fQPQxk-21fY97zT
# title PowellOptimizer.html, id 1m2A4Kks6QiI08KDUOeBgzmZqI2vXB38Y
# title CMAESOptimizer.Sigma.html, id 1T7EUB14t3xMaookFNjuQioQhhS_xpcB0
# title CMAESOptimizer.PopulationSize.html, id 1JHdPCv9GM_q9Wf0Qkqjzcx6J2nR-HkEb
# title package-use.html, id 12FenSafCrvKPAWu83kpcJOqJOg-O31oG
# title package-tree.html, id 1mFBRiE6vCub4Dpq1N7Dt3zcxkmqFaAX7
# title package-summary.html, id 1AXWjX6SCRYVYMj9zodoWJ4iwCxBLNnBC
# title Preconditioner.html, id 1pF8siK0fadNAvpV0Yx91KcF5Xx5uAghA
# title BOBYQAOptimizer.html, id 18Z57kosPpqN31hQ0MBEE0rDj_1SSa10E
# title AbstractSimplex.html, id 16K275nGxaCX3d2gguVFYRWcgUpYArQEm
# title CMAESOptimizer.html, id 1MqjXs5Gy-f2V1XXNK7Gfl23EjFWzL_34
# title NelderMeadSimplex.html, id 1v8DlwHL84zC35vINhAmV6COX_-Hcx20k
# title MultiDirectionalSimplex.html, id 161wNXZNgqDry-TpYQkQqL-oSSYfYXrRw
# title package-frame.html, id 10UTE2xTA67Ah3A_v4ZiTx2stvdL6N0r4
# title package-use.html, id 1IgjXqy6xyiTOOeFZFoma5hbBGXWih5mr
# title package-tree.html, id 1QQp1MQxnR7Lqz6puLde1DlmYYFo5N6mY
# title package-summary.html, id 1xiSIwhd9q4kU_gbejEpTOR2Q2AQe0Kkw
# title package-frame.html, id 1xrmBqbc22OM9IBf7FcyuzrgyNMBShmAb
# title NonLinearConjugateGradientOptimizer.IdentityPreconditioner.html, id 1ZTQr9zZyTZPhKidodCX62Hny5xMyZbFa
# title NonLinearConjugateGradientOptimizer.html, id 13pZP9Yb5QWfZoy547erniFYoeSJRt2Im
# title NonLinearConjugateGradientOptimizer.Formula.html, id 1n0DHszbB2nX9qPHQhl26-M3Wh5jAxLjF
# title MultivariateOptimizer.html, id 1zydAglIslbeie5k0rr4sesukG3skFPjf
# title LineSearch.html, id 1RddwuhECdJmspwu2PDe3eyWEEMV6hEwq
# title MultivariateFunctionMappingAdapter.html, id 1HbPPg1ID5XYV7QnboXMOVVnfICX56FoW
# title MultivariateFunctionPenaltyAdapter.html, id 1ct7VhOuUi6_blsO7KY2pbu5AbdPzSuUG
# title LeastSquaresConverter.html, id 1uOeoz8VobdjKeGn6by6YDvBT1eGgmaxo
# title MultiStartMultivariateOptimizer.html, id 1CYqiPldXQkSufejy6mKF7s70qyXv7O6I
# title NonLinearConjugateGradientOptimizer.BracketingStep.html, id 1A2YlFPrCSIAlehN2RsoTO6wR0fG8oPBt
# title ObjectiveFunctionGradient.html, id 1jRubSUSqUg5eZ7Z4euoYhZD83vyN96OJ
# title ObjectiveFunction.html, id 1CZXmNvFMZWg3rwcdJMOYZbUp7YqUcHZH
# title GradientMultivariateOptimizer.html, id 1kMojfzSqRtAOwWKl0dj1CRwWnj1Rf22u
# title GoalType.html, id 1tnl3VoOBioywK1P5XbaFZvFrS9DS9sMC
# title LegendreRuleFactory.html, id 1IjmuSDWLK4E6sbkpfxLlC9h2ktGSCe6o
# title SymmetricGaussIntegrator.html, id 1IHUBBs7ZODBgT5V2XqL9Po-5NOvhYkPV
# title LegendreHighPrecisionRuleFactory.html, id 1LeebHrzHeHNYmVaqSc62dCbX6nIAd96Z
# title SubLine.html, id 1EjoJgseZfuRqqBqgaHA-JrVjJ2usVM8T
# title SubPlane.html, id 1qFMBTCne7V9ZOqNMt2bJlfgvGXJgASX8
# title SphericalCoordinates.html, id 1f6DzTBEKyST3JkW29Gdd73yzbKkeHCW_
# title HermiteRuleFactory.html, id 1hRzSY3fg-ECBYicUaO41QPrsvRH4NAvD
# title GaussIntegratorFactory.html, id 1uMBNnOxQ5SZF-ne64Q42IeljCafbiq_5
# title GaussIntegrator.html, id 1Mw7KDM6LEDJE1Y1IUFZOIlk0ei0RfTwJ
# title SphereGenerator.html, id 1nX0FTqutyiyGsbQ0Bo8q1OZqzPCmJO4h
# title Segment.html, id 1EwH0483j24JgppoEUT4fhkivfQSFM_gG
# title RotationOrder.html, id 1nkhTutwq213RA4ANFp0gW9RXlYZdYJqK
# title BaseRuleFactory.html, id 1Xt2z6vrwlsgK0aByomzHOMMtyIX1CZ7R
# title Vector3DFormat.html, id 1AEBh-DefxHy8BTiTTTRBhTINz_dgozYb
# title Vector3D.html, id 1MU3iowCKYao1D1mSWgeaaYKp3Txkda1h
# title RotationConvention.html, id 1B-CstbA98MmciF7r8dFuALkgeole6PYj
# title Rotation.html, id 136sW2ECRnbNXIGJrS0WO1AqrNxope_SY
# title PolyhedronsSet.html, id 1NLGsLy6e88G5t7yVhgooivR4v0aPtrh4
# title Plane.html, id 1qj53Oi1IdOaEC0N8Xw483sWoQqQ78BXb
# title Line.html, id 1xRzn69tosKnS6C6t-4T-yGk3nFISv0UI
# title FieldVector3D.html, id 1ZnLHWgbXpZUf8L8Ya15qYEwfQMUazRZ8
# title package-use.html, id 1IKAPvO4JWO9XSkPCnkazOEUADK6PfYGg
# title package-tree.html, id 1pJ40ts5MfAGDHaxjd3mDS06FZt8r7uVA
# title Euclidean3D.html, id 18ttavohr6b68A6KuxC3XKng9wQ0P2Z79
# title FieldRotation.html, id 19mv8YtRahBCiyvCmT5wC2T-I46KDFLpA
# title package-summary.html, id 1ZHGazGd2nmntM6-Msiq94FVzEZydaCeI
# title NotARotationMatrixException.html, id 1J8UJL6H-loezUb6qzDwrWoMjrStM18GI
# title CardanEulerSingularityException.html, id 1ZnYFz7udjp2dPB8limtROEXtjK1yFhK5
# title Vector1DFormat.html, id 1KJ3TttnHc4-E91E8fLSMKWaoalTXDdpQ
# title OutlineExtractor.html, id 1EGEvRFtKnXEaIagCJ3-OkLARJUuN0APG
# title package-frame.html, id 1b5izd-tRMrcgcghj6rq_K_35Ai1X0g0V
# title Vector1D.html, id 1ycC7WLxGPZ_ObBbcJp8uTlLsTzuFVGkS
# title SubOrientedPoint.html, id 1CYbMoLLi9xoFeSvyXsvvlSKdJN6qT41_
# title package-use.html, id 1mBKlPUhiC1EhHRv6PtOxLKv739vLquQl
# title package-tree.html, id 1DctCEfj8th3S3HEfCpGy9tR_PzAyuyLG
# title package-summary.html, id 1LX96eijkvkXD1m0SwoFGPIYKMzrUEuMa
# title package-frame.html, id 1IRmIVH_EDA6j8PDkO8-hCUD60BHDf-d9
# title OrientedPoint.html, id 1l2vXoLLynlgeep0FKElKxiPhOSmaTOxp
# title IntervalsSet.html, id 1sOBBDStMl8l2BKezQ2y2YtXC3MbQp0_m
# title Vertex.html, id 1o0O9B9O14dquawUFgP7_iGugFXJd3Wga
# title Sphere2D.html, id 1nZqLTeUEZmf35Ok65rQynzhpF1PI_7yg
# title Euclidean1D.html, id 1AH-QxubH2-mlbSdW2UQWejIci37bR2fm
# title SphericalPolygonsSet.html, id 1iPBkDvjJvnGXO1xLApJ8jmu0eBxORnht
# title S2Point.html, id 1MDtmVFrpmE9SROlReT3a2htxS7j7XZNM
# title SubCircle.html, id 1GaXiU87JfMJv6n19eNvRFbH_OCxhYD4K
# title Interval.html, id 1v7aQm1rpRneBtzoj8J1qYd2UI9qpgCmj
# title Euclidean1D.NoSubSpaceException.html, id 1RH-q7K3aSYUZ9U3grEEDSVOx63Tq2kZn
# title package-use.html, id 1ThnvccHtSPHNeGuAqfZ6R-AxgUSYf0fi
# title package-tree.html, id 1p45aTckUtpEr5Rp7NLFoZGI_RV3sTpI4
# title package-summary.html, id 1siFqXF0FfLIh-0CFoHVraVjO8meRt0CR
# title package-summary.html, id 19CvhUksFeD8jTJowqFI5gsuN2T4kxCbp
# title Circle.html, id 1kelDXRGFsFan9tiGwwN4fESOL0c8MBBT
# title Edge.html, id 1g9QnV1V4X1W1mgJCSqNj866Pk-I6gmY4
# title package-frame.html, id 15yYBeDnP-xHXaxZfA6dQDfQ-bbWOLO1h
# title package-tree.html, id 1JyxyTpZ0hYmhKYGLaP49IkfFFwULc59T
# title OrderedTuple.html, id 123uhh5Be2BTW4fKUT-V3DmCLiYKT7Xzy
# title package-frame.html, id 1keHAdUOIA5iPYdNk4wsvzPCIwAJ-4vw8
# title package-use.html, id 1LecX5a29t6H9ZduPEbsvJ4m9JJ3t4dk_
# title AVLTree.Node.html, id 1O8kFffDduRZyBuaknFOzM-chuqjRamLN
# title AVLTree.html, id 19NoHmgHiaq_duz3CCQvxTCMezq9DZufz
# title SubLimitAngle.html, id 155YwjLGv2My_54Rn2ywq-M9TpF0CJMtx
# title Sphere1D.NoSubSpaceException.html, id 1yOY9NG1leCMLLBKbfXLNpdZn3QUuPtRZ
# title S1Point.html, id 1gcR46OMrydC8Bo6befQnlCBarE8lN_Y-
# title Sphere1D.html, id 17SLT8u92bvmfYx8cyxd0HGfWbqB4pA1R
# title package-tree.html, id 1jjitrPUja0cP3EOa9Es0dRXUCjUqk8qp
# title LimitAngle.html, id 1XX9r6luBlYJEvnFBJSicTNDHVNYZZUr-
# title package-summary.html, id 1j8TY0Q7IVSU7SqmRFL67lhUfPjpI_TMK
# title package-frame.html, id 10BgAOnHAf3qqAWywhrLIlpVAQR1WDcXS
# title package-use.html, id 14n4G312mqtxF3Ffq1kdKOtU1U6HNT-kR
# title ArcsSet.Split.html, id 1k6OjJp7h3iTjR13iH-Bt9FNutWqoSSPG
# title ArcsSet.InconsistentStateAt2PiWrapping.html, id 1Hsxx_tp5uXF7sls4L5mnqQsQfUURA2WA
# title ArcsSet.html, id 1baTXR0jivG8R7PWcVWTbQQ26L1r-ADjm
# title Arc.html, id 10Q8Sy0XJ938rZfL9JktSOQczVDvAXVpR
# title Transform.html, id 1vUXmEVFACN8ErEKO1P8N6N1ZlTcXv7Uq
# title SubHyperplane.SplitSubHyperplane.html, id 1o7PQUTljGlwCB2hs6NcZXeSxTZgkJ-5r
# title Region.Location.html, id 1iJpIZsEDPYs8Z-WfTsYMlZiukY6auJS9
# title Region.html, id 1NPUW2rkMdNjvlW_fqsclzx26LRWIRgSo
# title SubHyperplane.html, id 1I6WW9dm880HbR65on0gF4qqPw9WfEGFR
# title Side.html, id 1JiVDe684jauUZxLv42rdAJHOt49MXvId
# title NodesSet.html, id 1hcNsFHrvtoij3qEKlbHN832oPNfAbXtO
# title Hyperplane.html, id 1CEDoGXInQDXJiswHTvsqtcpc5G69MuOl
# title RegionFactory.html, id 137dnip0OQC-2xOSTlF1TGQyVRX389h9T
# title Embedding.html, id 1d-U5mKaBlU0fu099sZXwylC31B12VMB4
# title BSPTreeVisitor.Order.html, id 1ug-xzwDV5Gd9m0TCX7Hw2bUBByrk-jR2
# title BSPTreeVisitor.html, id 1447VCk4LIR2GklPtlTG4Mw4rmJ0tvV3u
# title BSPTree.VanishingCutHandler.html, id 1IO_SKOY2CANwX8KRfheraSHoMW9YKVm2
# title BSPTree.html, id 1cv_z2eeDpmUYGmDNrxJw1s4HmBW6F1oj
# title BSPTree.LeafMerger.html, id 1fN8mG7ok7GnHbPgSxST2Z_V3SzwF5TQv
# title AbstractRegion.html, id 1Zy55vW7J3XaVU71xMMDJpvin-gkpCgXm
# title ConvexHull.html, id 1XBTcXKrOHO-i2J-wL12BDTYHkdA8Iuxc
# title ConvexHullGenerator.html, id 1i6H4h21waHqD8EgscZlybYYT6cdZQgRP
# title Vector2DFormat.html, id 1YmumxlJkiYgw3m7mih9VrsJlwbauXHl4
# title BoundaryProjection.html, id 14CumYz4hzurgUsrdGKYvPX54Gf_LSRBi
# title BoundaryAttribute.html, id 1cMd48gvIuHGuaZXbq_u0WW4lmAMK2PqC
# title Vector2D.html, id 1hB0fGdudfFFsuUSwwaXsaA1b39_w1_SJ
# title AbstractSubHyperplane.html, id 1lRdwxKLSCTrnvKq-PFUVd03GkhRHz8wc
# title SubLine.html, id 1kyJQbAv3g7wLMuwfro3Fv6q8LxZlVNqP
# title Segment.html, id 1FpUSjAMDmWdJTsUGOTU9F_cZQPbuocbX
# title PolygonsSet.html, id 1ExHoiRpFAWmpwv4wGG--sByvtAKkXPbG
# title package-use.html, id 13LfsDD8XBGICP5wKaPEe2gqawdTwoMDs
# title package-tree.html, id 15UNkhDxgJ-nAHYEfn5BOpJ9aCvRjTrIK
# title package-summary.html, id 1NFCQHMXXvUV_W-LMk5TkqyYA6Ui_mPtY
# title package-frame.html, id 12IUgvsNAIVMiwulf5vRgfl30WXARXsVa
# title Line.html, id 1Wig2aMijNPf_p5PZ06hBuKA67dp4U_Kw
# title NormalApproximationInterval.html, id 1MIlhOP0jwW_jrMKyd3hHrRVqQFiBj1Qz
# title RankingAlgorithm.html, id 1Bm1zwvvnN5kYHWsjxhN1IdvImvhMLVHN
# title NaNStrategy.html, id 1X6B27wDH7W8yW-XcdPEPF9U_JIwqMqji
# title WilsonScoreInterval.html, id 1dthl7J_qQf4QAm4MuxgBLqNxgimRD0Cf
# title TiesStrategy.html, id 1_vIWMAEQdqDejEjjgTO68Fl48tMYLI7l
# title NaturalRanking.html, id 1GIEcSNr0_ht1qTxIiT9lzrzunRMoV1Bs
# title Euclidean2D.html, id 1jHnSJfsuHjT6qccZOrr4DhgNhGC8-Vj0
# title DiskGenerator.html, id 197KmpY9rxDbIrwtKBwociuyKdqhPZpcQ
# title IntervalUtils.html, id 1UJCYcrcWXzzSEK1npGjoAgmB8wWPTosA
# title ConfidenceInterval.html, id 1OJu0IZZI2WBE4DjKwS2EOpRkiTJGi1sv
# title ClopperPearsonInterval.html, id 1Uws1z_xCec3jvFnOmCjDgGu0xizv6zSu
# title BinomialConfidenceInterval.html, id 1pyzVypKoIDn8bZ4T-50YNDE2n6Cs1iSN
# title WilcoxonSignedRankTest.html, id 1vGH8nJ41vNg9LBiEjEVs9kTCT7t0_iEi
# title AgrestiCoullInterval.html, id 1JgXSS5ZqINFkreDoVDKkZAaaE4fFLDZL
# title TTest.html, id 1jtZAUIetrmCVny1yM-FVslRPdEggdqHo
# title ChiSquareTest.html, id 1pVKhmA1VEK6VY76NvjduKo9TRDU_w2MU
# title BinomialTest.html, id 1SXrhj2lMl95fN1-CuzkSvUPUQrDCmFEm
# title KolmogorovSmirnovTest.html, id 1vIbuExqpX1WPA3JZlZ9k_2pvY_jof3Cl
# title StorelessCovariance.html, id 1Lt7yxqZyaUzyM-ksmTmwah3M_43N1onh
# title AlternativeHypothesis.html, id 1ebq2p7_mey4__ZnFQngr_9ziyuGwbFbZ
# title GTest.html, id 1rbV7YlLbjqS_OpLVxAyjzLaY2GlR6hci
# title TestUtils.html, id 1OVm34KcAV5XFknvGjxPWvnvCpaBB3rKh
# title OneWayAnova.html, id 1yZsTVu7-nhuh6j-1nvxt4BcmHg1R-r2e
# title MannWhitneyUTest.html, id 1uF29Ut7hPQJejD2X7ZcPFuXh4Rki_Wn7
# title SpearmansCorrelation.html, id 1GuijMYkZs86Z5Rb95HhG-5ZpjykUQs8c
# title PearsonsCorrelation.html, id 18qJvexxa8l31n7fUdVxl98s6FpG66qvw
# title KendallsCorrelation.html, id 1KaoyL2oSnPGVBCGXrAISicRK-6cXFdsA
# title Covariance.html, id 1Vh8EnZV0dqHP_P7Qa1TaCW2A7IKPzliB
# title KMeansPlusPlusClusterer.html, id 15ad5oaY8HOX9mRAg7o7kEB7eEmUST6iN
# title SumOfLogs.html, id 1BNEbKj3OlkRzUNRn2ZDVPVFF-fpkW-4O
# title SumOfSquares.html, id 1vNxEFaRv3b7liiaPjsnHtONdK971roD3
# title KMeansPlusPlusClusterer.EmptyClusterStrategy.html, id 17J_4zH8AFr7Dgonm6hWDmlIBOI5Tliix
# title EuclideanIntegerPoint.html, id 16-ijzA26dEcKM2op4IuitVf9-WT3qRIf
# title EuclideanDoublePoint.html, id 1LRPmaNVZLZOh3G0xhEmC1Nyhtq0AhjwK
# title DBSCANClusterer.html, id 130f5qObOm7y8YobEhEKrMmx-xN_2WAoJ
# title Cluster.html, id 1VwjquIvjWY4qcMEhcyJ1vERkT53KPivM
# title Clusterable.html, id 19rSxytF_O7dBskw5cKN_-gxHx4dPFoSK
# title Product.html, id 1AcqspvG4pfbn4btRNjMZEQu3CcsTEkmx
# title package-use.html, id 1sQY_RPu8_icLElELY2JErkAADj9R-1Pq
# title package-tree.html, id 1W3pmETf9h0m7titvsgOBM-yWC2LQlr-R
# title Sum.html, id 1DlUCxP1puzF7H07Vi87W88kcIJJPn5I-
# title package-summary.html, id 1Ta1GPl-CdkPmQ-UgXubcaClftqKRBwu3
# title package-frame.html, id 1Ni4tTN-RcPsxXLspp9CXAijDPs-Htr4O
# title PSquarePercentile.html, id 1eVuWZz_AbNlZJdjXvxuX0kdsfi_pR8Ws
# title PSquarePercentile.PSquareMarkers.html, id 1ZlY1GNUGpWA9cahFzXgQOJKJA2pfEMlb
# title 187.txt, id 1ypqrHLs_pOooP3VvkyNm0P1OBiR6wuSs
# title Percentile.html, id 1_knoXU6CdAl4oIJgh5pflRmkV_DVTxxZ
# title package-frame.html, id 1mjMMyDO3mQcSH-d-mSfojlaLV1FZl9_H
# title package-use.html, id 1A_3DtbUaKeKxF9SkmOZ0IARaOW6R6IQY
# title Median.html, id 1XKnq6vGzSFVe1EJE-qh_i0NakPbp6BEz
# title package-tree.html, id 1Fb3dHt2AOadjmWaY0LGssbBDf97bPkUN
# title Min.html, id 1pvJuCJgTgXsHkmerJWuurhw-TMPTSHmo
# title package-summary.html, id 1yjrz6a2wWx7O8_4OBt6RPNvFAZaV46BN
# title Percentile.EstimationType.html, id 1nvqr9lpmvV-Rn485vdmOL7hCkJAdInuk
# title Max.html, id 1qePVXwC7mYBSBWPuC_ZyN0sibJAeppwr
# title VectorialMean.html, id 17rK_u948SW_JUxmZqjbdTqBnGiUjt94P
# title VectorialCovariance.html, id 1hdMKAdm82RzPLi0eomCTmosioAr2ADnq
# title Variance.html, id 11G7yv6rv6SkME_D4TzXbvi38No-xl2fI
# title StandardDeviation.html, id 1qAcMi-z1-XJgQnsgK_hwizK0odPAeeyu
# title Skewness.html, id 1jj_ObG-255JpniAjFMOrZYxSqUnZT3y7
# title SemiVariance.Direction.html, id 1FXO3zGBG8OSSP0kTsKyH3WeH3ebkt65o
# title SecondMoment.html, id 1YUmoZ3GQNYrK3EZrmUlIBCrppslskt01
# title package-use.html, id 14rLiuyyDYPns5MoaHDJ1CSDYkuCK15hP
# title package-tree.html, id 1BZyA6p0ODdoxDfGHlNCkIN_mqlfkm6uK
# title package-summary.html, id 1RKZNrSv67nV0l_nrZYgPj1hTwkbNL1Zo
# title SemiVariance.html, id 1f9zdFAC6SVFDgeupQuHwvLUITsIu9NNG
# title package-frame.html, id 1cQ51wntbybihkgcnJqjEfDz1gZvJnvAY
# title Mean.html, id 1iB8cgXbefBRHOT97m0yU97iBIqTwCC3-
# title Kurtosis.html, id 1zQznd9lM28ufvB75o4E3nsOPGymwA84f
# title FilterType.html, id 15Ezp21tq2Ygq106EMjMfw7PgIcZ3j1qC
# title GeometricMean.html, id 1zpQfg6xkXQ23RZN8H1nkmUUqeRK37lJI
# title FieldEventState.html, id 17Vzrg-I5NVHpAU9LN7Ys0Uk6xi3NSpn9
# title EventHandler.html, id 1KyzSunzJnTKY-yEAyK4z4eR4amL1Y99e
# title FieldEventHandler.html, id 1skRqkmKtiXWLjjfCKF4pP49u6obVLT36
# title EventState.html, id 1ZNi0kCYXbZOnbakVxD2f3-LLUdQHF0eD
# title EventHandler.Action.html, id 1BewN9Udga8Uc_Mx1LVOIt8lsOvFSddvR
# title EventFilter.html, id 1Wk8oy9wh0CKPL1pWYjmde8uiqoq-Hs2l
# title Action.html, id 1Mrul_KwH0IPPsvdouMh0eADrOR2Z1Qr4
# title package-use.html, id 1Vhm182MfEPysRbma2E24DBrOZCqoeOVt
# title package-tree.html, id 1HP-QuefFJY5AQBIE2uJabHF-ha-HDQxW
# title package-summary.html, id 1g85wnTgiZgvazHQci0q-l-2CQvp7NueS
# title UnivariateStatistic.html, id 1U-vZ9ZF6qQI7RJW8GCVinSykeaVTtCR5
# title SynchronizedSummaryStatistics.html, id 172bCpr63uuGsFwIcfs1zXUnj-UTBFtHj
# title WeightedEvaluation.html, id 11Gn5ZISelgi1XVfJgq7MH1Y7SyAGpz2V
# title NeuronSquareMesh2D.html, id 1jxJyYfM2jYJNwd2M9_Dv0zhgIHVTe6GM
# title SynchronizedMultivariateSummaryStatistics.html, id 1MOAJxKoi-w4rUEgNx3iY4V3J4RrsTBQ8
# title NeuronSquareMesh2D.HorizontalDirection.html, id 18hFCS7uPWtwLMZS89HF3bY5KGa3OknYS
# title package-frame.html, id 1MuPT1JqYYf7fvWAfIST-iyGy_L3-2WEG
# title NeuronSquareMesh2D.VerticalDirection.html, id 1637wjGXJ6f9jYWxOYtomONqjUSLK2vA2
# title SynchronizedDescriptiveStatistics.html, id 1rQieTuFREsjEHZhJymUFMJwTZWHiPNa9
# title SummaryStatistics.html, id 1bts3lqXytjULPwQvBumMyd9YIPXE-SPu
# title StorelessUnivariateStatistic.html, id 1gxi10uY_cjrr0hZ8_yQAKfqkl3tIB1NI
# title StatisticalSummaryValues.html, id 1RK7QzXa9qmxh5DaNE1Q7U6-6eGANsiYF
# title StatisticalSummary.html, id 1-4PmYF0lsMUHQyENdhP0NEFqVhl3QJHD
# title StatisticalMultivariateSummary.html, id 1h3NVmTlevvdzpaYpoZNtc7hbyl2NsPuc
# title DistanceMeasure.html, id 19QwrhhfOZGSQagwd0pWHiBtnj_rjVvKN
# title ChebyshevDistance.html, id 1annMLIVIOP9GrefEQNHYoI_ndinAEWgU
# title AbstractStorelessUnivariateStatistic.html, id 1I_ScOuQS_-CbVEv_BvM0H_-z7hUWra5X
# title EarthMoversDistance.html, id 1rgscMDS-FkblEbva6JbnsijW2Yb7Z3SH
# title EuclideanDistance.html, id 12ycqxNEVI9q3qxoFrjfvm2Muw5RrOIuI
# title ManhattanDistance.html, id 1-0RwQ71r_LVrhhL0SFYnDObTXlaNsy-z
# title MultivariateSummaryStatistics.html, id 1c-8DUVHi245Y3bCh6zdKGotGwWzhvFdC
# title DescriptiveStatistics.html, id 1AiMdpyUWtxQXQfiVnLdypRkEJX0onLto
# title AggregateSummaryStatistics.html, id 1kYG8xMGb1lF3w-LtbxnrLSSg3vYmUcQ4
# title CanberraDistance.html, id 16OdjJH-WOxnaplgGC6VKRoRn-0wXkoCG
# title AbstractUnivariateStatistic.html, id 1s8FQEo2N6SloQsAEhz63KhPLQguUuZai
# title StepNormalizerBounds.html, id 14QQoCwI9CPrcNX_0I8rOFGhHU_g2Jvkz
# title StepNormalizerMode.html, id 17l1WacP1OF8cu-c8B2Bi5uMzX_NzdUUa
# title StepNormalizer.html, id 1KMWP7LrWKlzRhUvovKGtO2s1y7jIfmd6
# title StepInterpolator.html, id 1C0rKXDxM-KzlhJfhEgl2PHEt0cp58hGf
# title StepHandler.html, id 14iegx1e6O0l9qvZz39kGy4asQaV2V20z
# title FixedStepHandler.html, id 11aPj3Ywup_L6zCgqXMPA3hhrMSYbqZHa
# title FieldFixedStepHandler.html, id 1q5VactegkX9ZJ92TC2djUZ6dZnL-_Itz
# title FieldStepInterpolator.html, id 1Cf8_z6lK-uMZT8CuRNfCKe3i1gfAYtZH
# title FieldStepNormalizer.html, id 18j6aaaQ7qsib3ZqAHovzsX3iiec4S0Wt
# title FieldStepHandler.html, id 1N8U3V4TRqGqq1NT8Da4bxDPVNd41hX8Z
# title DummyStepHandler.html, id 1wh9yKMNMIs22GsfGnJJZJFb9bslmvUiw
# title NordsieckStepInterpolator.html, id 1Sg0kUUB2WUfdV7rFxWtK1V5MKKAl4ZnQ
# title AbstractStepInterpolator.html, id 1rwRO7VZga6Rd1n3HEgjUAWqnx7Yt0RTI
# title AbstractFieldStepInterpolator.html, id 18IMk5u_HtzLmzxaet_3N-YwMQOSqK6fl
# title ThreeEighthesIntegrator.html, id 1mIB-2RCHbcBE9lMg4CgWoIxoEP1giF1S
# title ThreeEighthesFieldIntegrator.html, id 1biqQbwM28WffZ5hg57a0GoTT03EFG2Fq
# title RungeKuttaIntegrator.html, id 1oDbTIbHtqJPB5r1VJGDec5Il42Fq3JWk
# title MidpointFieldIntegrator.html, id 1iayE19Wio4xx1BNWOtcCMr5-0eaj-Ohh
# title LutherIntegrator.html, id 1qbq_7lzNUwOMAtSTdfUwSDtCgszWF-LY
# title GraggBulirschStoerIntegrator.html, id 1i2Q0kOnz3iKgPi0t0ZY4hU1HLOp033yq
# title HighamHall54FieldIntegrator.html, id 1UPfwWReSpXJ9eef9te7EdnvQcIKmnEWj
# title HighamHall54Integrator.html, id 1RG5183wYaaOp56mNRVdzOJK29q5xYWMo
# title LutherFieldIntegrator.html, id 1Ceg6sHSDWJht7D9MiZWjg4hIRk-EBTL5
# title RungeKuttaFieldIntegrator.html, id 1Kgf30_iknxD_g77qaGYiveNiCo-SX555
# title MidpointIntegrator.html, id 1Gu8mysVg3lboogEPtoLOS0cAhk32IfNU
# title GillIntegrator.html, id 1Tg962xS8u70rdF-CgiqdGVO5KbRjWiAc
# title GillFieldIntegrator.html, id 1SKqTKBsqPzNHmkwtWX874mbkFlMH1EBu
# title FieldButcherArrayProvider.html, id 1VCu_Vd_w0AvTNTSR8tRH5NrEhmi0zspw
# title EulerIntegrator.html, id 1YUuOKnrnXvub5ftg9dRre1GiyGXk3bLZ
# title EulerFieldIntegrator.html, id 1ygGsYK2t970Rccp4eG-yBz_wDVV1vdhn
# title DormandPrince54Integrator.html, id 1sTSxfUyhqOX7UH_6BqQeQwlXArflm7a_
# title DormandPrince54FieldIntegrator.html, id 1d5tvAwhK7r1bwjDM92osWBngCztZscC7
# title ClassicalRungeKuttaFieldIntegrator.html, id 1QuTw2BoIIwtYKIfhGufeiyWU6He1_rY6
# title ClassicalRungeKuttaIntegrator.html, id 1htyNa3hES8CyOMT9t8-TS5_MWlZWeWHG
# title DormandPrince853Integrator.html, id 1ygZ37RBgZVcJOQjxy5PEQ5BenUce2rnn
# title DormandPrince853FieldIntegrator.html, id 1cjwgGRuhSBvScNPo1pq08mIOEzMFTB7d
# title EmbeddedRungeKuttaIntegrator.html, id 1HxdWLRZheTYdtMt2xe_1FTBk5Q6-Vyzy
# title EmbeddedRungeKuttaFieldIntegrator.html, id 11VU1eqLzdfmR122qNx1mhSJhHGWmXvJQ
# title AdaptiveStepsizeIntegrator.html, id 1uT8Q_R6Z8_zrlIOv-IZIh0FrjLdwk9wZ
# title AdaptiveStepsizeFieldIntegrator.html, id 1K1S4d-UkkVespXMDwUFQ-Dqur8-dIg8e
# title AdamsNordsieckTransformer.html, id 1M3vGnuauzjVq-909m0ulKKWmavlsj3T3
# title AdamsNordsieckFieldTransformer.html, id 14ptVR4k7aRNNDhacsteNV95EPzT3uvg9
# title AdamsMoultonIntegrator.html, id 1xtDuO-uZGhHmXR3nc_NhUqD_ANG3tw26
# title AdamsMoultonFieldIntegrator.html, id 1Qaa5_7GPcbnNB2vo2QShwKgSDH9LB3dL
# title package-use.html, id 1cOdritwmAkPXut_wtMb9_mrE5FZwrUu0
# title package-tree.html, id 1N1DXqOXSAfD9PgNA-rUE_Aa_O7L1Afbd
# title AdamsBashforthIntegrator.html, id 1VBLhyps5og5W0mu2nXl-BAweg5G3iAJk
# title AdamsBashforthFieldIntegrator.html, id 1VA9xgkWcuIqQbgLqviKIcF-vvIHJ_DKn
# title package-frame.html, id 1JHeUGb5xD_Y1BJsCAaNcdDdZylVan8SL
# title NeighbourhoodSizeFunctionFactory.html, id 1JfNI-kv1n7JrHdS_tYFGvtWAQCAGxqpF
# title package-summary.html, id 1CJkNH9pbHd9HoOR-_p-KSdzZaP2Zgr1U
# title AdamsIntegrator.html, id 1_AtffZSnuG9gwRXkpyHXv5JDsrwIOw6U
# title AdamsFieldIntegrator.html, id 1N_NLKBK3sVC1wqINEpfw18Sw85WfyP99
# title NeighbourhoodSizeFunction.html, id 1jzFbb_NfmzqE1CxzMEPs3LQ594uzGlVu
# title LearningFactorFunctionFactory.html, id 1SSAvjpbp1XUv69ZjyfuflsGBrqwstzh1
# title KohonenUpdateAction.html, id 19TsZ_46PgF_5Y8NQqyXqnhUek0KyImxB
# title LearningFactorFunction.html, id 1cryAezOWn4o_nRbr4osqVNT2FShnnrN-
# title package-frame.html, id 1KVD7air3ouvvUQR9tIfZ3QhpQU2k1xcV
# title NeuronString.html, id 1oMhI8XS8Uyb4YNY3z3ba2al3mwxj8S6q
# title package-summary.html, id 1wthg_SWa9NsbnC8-vwNce9UwKFcS0bMJ
# title package-tree.html, id 1x36a1NINi8voJ3kPM-OZUD5WdeGNZhmZ
# title UpdateAction.html, id 14_mUiqNdeUUWdE1-pnxXICqaWJ8TZH3x
# title SquareNeighbourhood.html, id 1T68cOVqm79-xQMlY6ob0xWCeBy3F66e4
# title package-use.html, id 1wEMbMlU2P2PCUoIxGhcoG74qOgENlrDj
# title KohonenTrainingTask.html, id 1Q561zgIFSuxG_y4eyJowjjPw3JnZdgKi
# title Neuron.html, id 1j0je1Hqr1Ubxke8hLA6boU8ZzjtOhY3u
# title Network.NeuronIdentifierComparator.html, id 1DHZK8y2vmH3_5xfqbLakjDfr3MZTU5RD
# title Network.html, id 1ThUoemiK3MVEV_CWwiYoKaid9nCmcX4L
# title MapUtils.html, id 1aBDjj9kCjRimQf4LKW_Vpyrl2dOwkj9C
# title FeatureInitializerFactory.html, id 1o3CyLIo0h593eV6kntS5rc3ay59e0sWn
# title package-tree.html, id 1BqG-ZU-jKeR_KuWLqLiJdiBQwyCFRg_b
# title ClusterEvaluator.html, id 1TrzevrQ1rquyi-_obINw22Wt8qYMPhko
# title SumOfClusterVariances.html, id 13hGsgDY1PqqVdI9PONujRANUq4AVLeaV
# title package-frame.html, id 14O6G4BhwYgnvMugkkE4u5KDd7aF66_AQ
# title package-summary.html, id 1QupyeOBBorySqWxrLr1T1_XnaBRzWbE_
# title package-use.html, id 1Mnnhy21PjTRDT7VhOja7-3jhYrEkSECB
# title FeatureInitializer.html, id 1cYw9UIj4ha2M8GMQiEgKYAnNZAL8k8k6
# title MultiKMeansPlusPlusClusterer.html, id 1EUisz5xbgXdlP19veSLBQWdBvZcuIZjl
# title KMeansPlusPlusClusterer.html, id 1L2_NsEEB4JUr9DV3EQ_X4tzl28DWSBhz
# title KMeansPlusPlusClusterer.EmptyClusterStrategy.html, id 1mR9ilDMkgwW4fzrKl_c-yN1L635ryfR5
# title CentroidCluster.html, id 1in-ogmmaBoYnHJvbCUcOhLyo2eyXRD4y
# title FuzzyKMeansClusterer.html, id 1Gf-Af6a2uKNT8J2SGeUUUpaH89WGOVkI
# title DoublePoint.html, id 1SgGp3I9hOJ7QYCobe4cuRGcExHhYB9gX
# title DBSCANClusterer.html, id 1duC8dfkfbu046DXexvgpORlrmqf2pC-y
# title Clusterer.html, id 14G73ZnBI0OtqF8H3eUathEasXeHWDA_T
# title UnivariatePointValuePair.html, id 1PbZHhK6eXZXJfuv10rX1XPUidBwzxz6m
# title UnivariateMultiStartOptimizer.html, id 1x0r-UeNR8NOkN23XJbm_1DYU1FwYSehX
# title BrentOptimizer.html, id 1sTXE1a313uECaclnRH6CJA11RdCceS2j
# title SimpleUnivariateValueChecker.html, id 1a93uPj6-JmXAkO_KonSsGi3f7660qouY
# title UnivariateOptimizer.html, id 1_y5x9WH2os6vtGlbIRpwcA2rWJTgQGIk
# title Clusterable.html, id 10jhOHAI1uPlsnOw-SkRrJ9soGuhn9twq
# title Cluster.html, id 19U8yT7ejXDIYqcTOfbKM9YASmdVAR7ub
# title BracketFinder.html, id 1-LgA0rZbDv1V07P9HfoQvqTBTRnbu7F1
# title BaseUnivariateOptimizer.html, id 1DgXdYzjp7qYCuoTuFyTF_8xfU0w0K9iH
# title BaseAbstractUnivariateOptimizer.html, id 1V-3GUag59q3gmjZ0YsEVblsIZHOotRIC
# title UnboundedSolutionException.html, id 1VEP6tQlwJuzURaoFEA7WHNJNiO42Tdve
# title SimplexSolver.html, id 1l1A3xZDpKFgZ8Fh1MlMqC7kp4YaGrzuT
# title LinearConstraint.html, id 13zOesh6yTwDF-vKGf0ex4BMkLT9WN-_U
# title NonLinearConjugateGradientOptimizer.IdentityPreconditioner.html, id 1noK5d1rjOJw0LlHVGDJbe4R8Lk9ZEtkM
# title AbstractLinearOptimizer.html, id 1BEZnR4CK7SKB2i33R1VatbjCH3ozPUrd
# title Preconditioner.html, id 1qW44GFbYAVkMYMinnwmsIZ_gCPbi14CA
# title LinearObjectiveFunction.html, id 1WO6L08KsyySWGPeIb4cMwkTYW9x558sc
# title LinearOptimizer.html, id 1ErTHQZVuSID0nP8jCeMdisDWew_pzaC4
# title Relationship.html, id 13zYE_t9_-CHq-fZdcqy3qRyEFkZ4hgkf
# title NoFeasibleSolutionException.html, id 1TtWwX_46NOei2QFi23sg4Y6YvBS11DCS
# title NonLinearConjugateGradientOptimizer.html, id 1Qon1n1y8eCFhgV80SJ2UdgxRHPc3nkzm
# title LevenbergMarquardtOptimizer.html, id 1BzMm_W85nvJtsjp5ofXr4ruh3INFAMyT
# title GaussNewtonOptimizer.html, id 1OZut2HYkbGlKlzJH0RHeMTLTuepUT26N
# title ConjugateGradientFormula.html, id 149UcDETttrjWAthh4jLpXm-7928ZWZgm
# title AbstractScalarDifferentiableOptimizer.html, id 1R7138weqVjLFBej6gYyBYDBCOQsp8zPO
# title GaussianFitter.ParameterGuesser.html, id 1hv8AfmMdv7S50D4h-dznVtyszYd34Ecj
# title PolynomialFitter.html, id 1pj60Nl2wqIC_eB5Dg4p3S8X9R2j8D8Re
# title WeightedObservedPoint.html, id 1chpJhfj6Ou_EprY2waRoLQZOExTwDB13
# title HarmonicFitter.html, id 12KNjM4_L3eODVeoqkhZ-Zg9Eo-cib856
# title GaussianFitter.html, id 1P6sA1jGo_38ZL2tX0oudaJ9Oa3U12av7
# title HarmonicFitter.ParameterGuesser.html, id 17Q_abogPC_pwwHd44DZhYjKDKXAw_Lu2
# title AbstractLeastSquaresOptimizer.html, id 182uT6oVMJ8QrkraC8e-WH9JikFtePVQ5
# title CurveFitter.html, id 1LcHTWNAbDdGfvlyLinu9KB_RV-k5GYkK
# title AbstractDifferentiableOptimizer.html, id 1XrpqSUBSZeKodIafAlI3xQ_Tj_DL3vsM
# title SimplexOptimizer.html, id 1zCPckKFi3uohyORrtCrMochTDiGNkOSz
# title PowellOptimizer.html, id 1-bhAfeJSJj_fjgHROZYRPjN5Z4GgnmPd
# title NelderMeadSimplex.html, id 1D2gEdWgAdCO-3sOWxU4gofGevDGMKGHT
# title MultivariateFunctionPenaltyAdapter.html, id 1ZdrIp58bKbaEXBSpYu0JYzXSXUWHZFM0
# title MultivariateFunctionMappingAdapter.html, id 13a4heblk-Euk06Znqf3DvtulA1tDycke
# title BaseAbstractMultivariateSimpleBoundsOptimizer.html, id 1B6GgB2MJ68KBEN2PrvxspDjvax8aUGUJ
# title CMAESOptimizer.PopulationSize.html, id 1ANtH4_hRpWzV6JDHFjfYv2HpVp6KKvaq
# title BOBYQAOptimizer.html, id 1k4mQXCCxbrHtQiTK_KIWpGaRTCdc4K1n
# title BaseAbstractMultivariateVectorOptimizer.html, id 1Szl1JjwrR34PHuU4HeWRd2LqjyGUaGnV
# title CMAESOptimizer.html, id 1zWro0QbwGbw0QpwSxqUHOHcaymSGs6Ok
# title CMAESOptimizer.Sigma.html, id 1_nhIJlRKm6gFO4S3cC-bXBEDFxvKJfpH
# title MultiDirectionalSimplex.html, id 1PqVVRAx-7VIatJlbyVTDweGLW9m4bx0G
# title BaseAbstractMultivariateOptimizer.html, id 1YepRpd7xgt6goMtgEPskjl1z0NTVTmjC
# title AbstractSimplex.html, id 15tSfix88yzKhgysyHhXs8z1Cy0lNpit4
# title UnivariatePointValuePair.html, id 1CAmLWpuxomOpyX5TB4FdCjUCsFOy4fGP
# title BrentOptimizer.html, id 1sSIyyN6fsZvGgw0uXi5OvSUjQKwaiTbw
# title MultiStartUnivariateOptimizer.html, id 1gc7MHWYeZ0W5k6zT5Kher1FjMim5m7Rt
# title UnivariateOptimizer.html, id 1EBV6ghhj0nalMZ-vA1g5mwtdg1Ct66nw
# title UnivariateObjectiveFunction.html, id 1NitsL7HYEVt4q9KB9MGOPWdMWjwWkRB_
# title package-use.html, id 1uYbH3Wq1_NqOmXhP6aYb7AcfpDw2QeQi
# title Target.html, id 1uuVacc4Ua8_J-ZzIozdvAopt-gX6McLt
# title Weight.html, id 1UKytiFC75_Lqpd9MOWN2mkkNBIqog-iL
# title BracketFinder.html, id 1OGP1ho8ZyZeC0et1Tm231lawZ0uM_if3
# title SimpleUnivariateValueChecker.html, id 1EUg4J1b6FeAljub4IbwD2pJ05kUg6WSh
# title SearchInterval.html, id 12E56qgoNcnczyO9pkQDv4BWLNNS5ESTZ
# title package-tree.html, id 19zZxYDCApawKQ6CtGmGQbArNEY53vI7b
# title package-summary.html, id 1SWN9cVQfFfIqmPCat0yqroF6K8LpHGC6
# title package-frame.html, id 1esorxNs8i9XlxirVnN0frwKBvUvSR7Wl
# title JacobianMultivariateVectorOptimizer.html, id 1WLXoXwz2p4q2QRMw_CeHH5JSYOpy3hlg
# ...
# title ode, id 1SZbhFHke6VIoYZOseQB9wp_mwuno9C3h
# title linear, id 1n4ld_SUjtD2PvgGtbcRJ7v58aChU4drc
# title ml, id 1lhRH8NgppgE6hAITGYVso8Fq9dgFL0vp
# title special, id 1dtpyITP0BPgSaLIfSiJWt89xMp6v3Q58
# title random, id 1vBBu0m9paKN5hr-PXcz7LMipNALY0mmg
# title primes, id 1lxiH8MGyFwa_Jtb7QicdXehr3dOTLjQI
# title optimization, id 1Ny2Rv4dYJCmmMttUT_MbPBqhs-nNxWCH
# title optim, id 1SMti27tMVA5S9EawX3MINpy5npZmc97z
# title fitting, id 13wqendVJ496AOaYWqu_cDTJSw72D6tMU
# title fraction, id 1NHttpduc_FS-f6ThxfmogHwlo-YZ8E06
# title filter, id 1J4GR61J1R-t11V4P4fiGQubpRppBKX5_
# title exception, id 1x9y3xUcTVeXvnGMVbzlYvchLaaUBzh_D
# title class-use, id 17xsKfyrmW-C23xnYjhADyOuhNL4Gwn0c
# title distribution, id 1lOCBUJZXcbLBuHWefK1Beseb-hReKYOs
# title complex, id 1YtgEE9wucTw4S2s8fC6dx1sCwW_A-8Xx
# title dfp, id 1jnkc7fyPc1aALHNoT29VdQRSURn7fRwZ
# title StandAloneAnnie.java, id 1mrTM1Kgqq7-Q3FYdbfEMRAUXt-Iw2buY
# title skynet.java, id 1SFNXmLWZ0JCS4gHD_BvfuSDo1ERiaN2u
# title weight.jape, id 1razVp2HhBS5ts790P23qrGSWE2CPzQ2q
# title analysis, id 1Lam7WaHXMRRDTtnmV8agKflxUiPn5cl1
# title reader02.java, id 1cTpEnoC9i3CMOCNspTEGWL5vWcvBlYAv
# title trials01.java, id 1G8l37ZE3wB9uB2OuqIHx6M-cVat9uKj1
# title reader.java, id 1tkRaqdyRXxFplBhZsQlFAV_PGlI0GPg-
# title reader01.java, id 1TNBvLkM3T6c207xj1MaYMydce45Q8Uq_
# title test.java, id 14hHw--gjWo0Wc8l0Z59H-TSkKbcPr3z2
# title processingPipeline.java, id 1aL5La91acN4Ip_hbfp_P7u_y5rGoUwR4
# title preProcess.java, id 1jeafp9rPelYmxiPvE34eBFWe-CvuXSiS
# title math3, id 1lkgav6CJ7DaIxQoboYs8GGdkiOkwRTuk
# title gate00.java, id 1zRmVSS-0lm3izIRYNryo8s0t5UvHglh1
# title Categorizer.java, id 1Qu4GhFcGct4lWGYgakv6s08fhFAhyJ_K
# title backup.jape, id 1fqkHSqrCJUDLFBOpjXoTVVfZ7rBxuY9J
# title price1.jape, id 1JmZDSXkqKzwMg7-lBg4N4A1Q36XtnrZ0
# title two.jape, id 1JyxiL5epfYMn4MMTuXN8cd9VpDG_E_N7
# title commons, id 12oF-1wIwduvRM1YW4DgFM7JZanK8z_SR
# title trial2.jape, id 1qHzhiGu4RAsSsHh724k14JrfY7Hik_0d
# title dim2.jape, id 1CicmaGINlG9FI8VnUIFVv4o_nf1nTWJ9
# title price2.jape, id 1tSAFfC-2jMekH9ZCEXGtgMDVBDRBd98d
# title quantity.jape, id 1j9_nDJJLxyNZ0t5ojcOP4DJ7SNeWorIz
# title order.jape, id 1FA2qV7oS3KB9qdPOWBpcK885A0hrVmmU
# title product.jape, id 1kkbedmvkUPog0qAVdNJasmyQ9ghlHuXb
# title trial.jape, id 1c2nQplrBDThxfMFyqvMgfA5G0M3sAygl
# title price2.jape, id 1PsgeP0EDClSKfUCPopVa66-vPpDyhsBF
# title product.jape, id 1R6TMsu5d3yHIhXyMAQIiwK_M8Y4vHd4d
# title dim2.jape, id 1zF0rJn7EGPMWBdbH7ZZgWpOraZ0Db5jD
# title apache, id 1BYoiZrXRKbMwzyoAtuzO6OOEEkDJEiit
# title price1.jape, id 16SSdiakKavZCsje2GvMjuR65IlL-qyMX
# title order.jape, id 1CK5zOXpZbjdMeAeNuHkj6CXNsuvBlG8x
# title backup.jape, id 1PtoDgbh4hKp0PK-iIVq69m3jQSHkvjtb
# title resources, id 1KXsdLjILo77Klb0YTUsrOm90EX-b_AcO
# title org, id 1Cu0UY50iKDBF19-F_HVqwmqXR_qrCcZu
# title dimensions.jape, id 1KNrC1Q83DjZyl43lIaJpo308b1pywx9o
# title svd, id 1XAICmDfNBm_t_h_eFFNfNVSagXQb4yHa
# title all.jape, id 1MrSXbMuzsYENGnvb2vkgTYc2diwjWAqH
# title gatePractice.iml, id 1s0CCMPykzplqWKkVhV1TjsnK1UXXN4Op
# title rule1.jape, id 1ZXFQaOcXx1RlO-qEu6UTv_glyuBYBYUw
# title vcs.xml, id 1ro6za4iv7ZdOy7F02mLYsEH-ppnS3MmV
# title apidocs, id 1DLto01n73owFnyOwt5DW4wQ7MOz70sc9
# title workspace.xml, id 14Z-3B5UC6sAMJl8VkXDYVNRqstyibBWZ
# title index, id 10i0vj9yI7Gw1xjvmJv9MlyTdw0nC_en0
# title modules.xml, id 1sJl8-Tj4Ee-PXXpuF4Vp1AExRkhfgQVZ
# title misc.xml, id 1U4siGkZxVyKreHzhAcFSAyPUNfSDklOX
# title ORIG_HEAD, id 1PrRSrX5hP0NQZuVOVQ4Iuv1_Y2awmkBi
# title HEAD, id 1fyZSzmPKZ08CfalO1Xi9WixDxHcF27CZ
# title ~$CVR-TSL&DistDownloadWithTextFy13-H1Fy18CM.XLSX, id 1Te3QYSnfs8wMa7wb8DgVbWM8PYYd9Lkl
# title TextAnalysisTS.iml, id 1IqmupYNKBXaP7uRQhmE3p3AaSGePnkOi
# title heads, id 1NkIWhdZzsyfm4WLrRiLGWqvoRgb-ecW1
# title docs, id 1lH7WS3IeGaH-a0AqsB9Vikp8E3TQPDTF
# title tags, id 18Nn9GsLwtvA2mq4ljh1PF6evmN7MFtZE
# title heads, id 1qfoT-C_5r1SAlekYZ0W0BbpdiP1lr0ls
# title info, id 1wv0lzWGpWfdQR0nkQXZvucsWIwn16iKJ
# title pack, id 1F2EdSjcHicamDXsAr-jQ1HxLGYHgB-mr
# title fc, id 1u74qN2MGz2-EfIUmCHC9CO1AM_lLb_AS
# title ff, id 1IaDSo5oX2Z8ZGCJWUo93IUiFlGoLuVWA
# title f7, id 10q62mMYS_W1TKTCTGNSdB6G6h2zIg4rb
# title CVR-TSL&DistDownloadWithTextFy13-H1Fy18CM.XLSX, id 1P17g21TC5or4hnT38pgWrE4PhWw-tP04
# title f0, id 1m_tfe2JSxakXi7Ohc-Crvntlm24NthUB
# title f3, id 1qxvMhUV7foZsuwbnsmaboZR28TQLYDDv
# title ef, id 1soSYwYyFWUeycQmZUQ4XMo3bXFhhxSko
# title ee, id 18YC1ZAEwqjTGiOYN9g0EL4WVBck6uuzj
# title ed, id 1J6gVV1G0-DiRdojlqenpnV_POp4iVRQ_
# title e9, id 1SiiJncUuOYxaPwarOdCJsK_QsctfBFUp
# title e8, id 1VfDucC2wBzFWNvHLT2WO5DiNHFIzjRKx
# title e7, id 1Bdc72ABBSVjvlWWXnD1z-YVcTY1OvXhi
# title e6, id 1502imv1sXi0yIbuI_KoI-_f6NtG3Vtzu
# title da, id 1dfcaauzoF_lz4ZumJtZK6O5NrkL7LW80
# title d5, id 13EiNZmEt9k3FN2vGOMiz0AQZSQg9oKYN
# title d6, id 1fgdNZrBBAHYlHlXYVYEOviSQbqPKFq9Y
# title d9, id 1SbdYvjnVWejuIi5Xn2lFr-Sba4U7-9AB
# title d2, id 1KdPE8p6mMhAaYb2cTEyj2leZCmPC8RBx
# title d3, id 1b3jfZX03rWlGnemJ2Hxf6JnRcAywToh9
# title ce, id 15qxp7PTHaWggA8jAEyoLiVhbgnjop0o0
# title d1, id 1kjvG7cROjs77TiyLQ2gdx5Q4AeNoo8Kx
# title cc, id 1E1NC0Fix7CGHe19kPlxNLTIl9C8SmCBM
# title cb, id 1WDPzI6HOVnJGLVKZph3EJKOdkiMidkQJ
# title c4, id 12RyoZuMSBfe-ecZH3T5LBnQLlOQtzVco
# title c3, id 178hc4wfMs6l3l_AbgKSXJeMShmStwyZL
# title c0, id 1S12WYSps6IOJvtgjkzSQ901SLOM-yHp5
# title be, id 1ONwprU7BtNDthjobr4tsbA4zX9T_wPfT
# title b2, id 1bIRWrnIKQkqxDtGSBmgtSbsGBSJlENB8
# title bd, id 1sVS0Lidv-zpZhDr_h_07VVLgvr0CjaaT
# title ad, id 1_VhvO4pOCHJUjjlW-PlLfY0DVfClt6Zi
# title ae, id 1EDk7xAVUOlYv9nKkre-726mMfgDLKx77
# title ac, id 1tKRQbyIk1Y8wq4ULxOl53eFEIuMj_ZJ4
# title aa, id 1_CKFN9PGF96cIWVlAZp86znUao_482eL
# title a7, id 1J5B5TuFWmNve8UiSdb6Xy7CNVTBS7Xd-
# title 9e, id 1AoAjj9YMrODZP1LBwIIzAOz_Vli5QQoy
# title 95, id 13gAqhetQFBuhjcjLL4_6u4LNZAuFKbCX
# title 9f, id 1CYmt1zo1vUCI2M02517eeDFr0Rx0aHJ9
# title 94, id 18oyixW0F0J1cymqMs_8sX7ZLjrwtl9uI
# title 91, id 1Zw7NQmEvkPRG_Vj878z-LyFBUxsuub28
# title 7a, id 1RZ-hrqHIzBdHhMrALhks8LNSEXpmmgki
# title 7d, id 1OHB749ijDDo3FJyL1h-A6iIj-gID0H_P
# title a5, id 11elg9aHfgRSm2PXC_pVwjKQvZd92x_oW
# title a0, id 1yL2DtHWQAhyvw-bqOJzKm9AvdqhjAFMm
# title 8e, id 1JjRSZDVndrmG9FVWQMsJKmopFUfqWFJl
# title 86, id 1QOqzL5yh31KorR6sK1XLsvf15tcjWNrR
# title 85, id 1ZkX1DpviRsdNCng4vjlUYbPxEI8U4-Vp
# title 5a, id 1wVSpOU9_I_rsQmdz_l9qLeK3cW91ptpa
# title 5b, id 1ATKYChzLYuEiFTWu8k2HGogeZXDbfcVD
# title 57, id 1WnjuXCjYzD0SSQCeETkf2FRWlQKCppIr
# title 83, id 1_g3dvIbhZFxkfRhiAikodGqjgFeYRavz
# title 81, id 17nW2ZKibVeCiHUSk9qvZcX_KimWGhOVv
# title 80, id 1LmVJEsrb9Z2383cIlOZU48-AdM34lX5O
# title 78, id 1TKOoRDoa6RZlsqvITZLUN9gndUmKh6Q2
# title 77, id 1CzkJFPLkq3J1zPwNd5uDhH7a0EJLXOk6
# title 75, id 1oVF_xbgFZ5KsegFR4KBDD3uSKU127qxl
# title 64, id 1n0GUsQJftu_edUtgsZXQnCiQt-TH_0yb
# title 65, id 1x6Oddzs8gI74iNHUrcGYtMGRYk4DuVvK
# title 6b, id 1Z0ZBxGKvVkVpyK-zRvmqzOFm9XciEULW
# title 68, id 18gMGdxxRm1fmkR_QvwfQ1JaNuAB-rv_z
# title 67, id 14JxbAzTVYBUnMFdsQps6Un2ymoaLOaYb
# title 5d, id 11BxUUdfB4MPdZIHvNu8nHuPfIx2jzQbj
# title 54, id 1P9DlbCJF6gpVU-KMwJiXVp76ecMEo04E
# title 44, id 1HZGAhUO3pPwoYM7omULh6IDAtHSRvQTd
# title 45, id 1eZTNZuUxyC0Tfw7bNU4o0vJwT5XI8Y7S
# title 53, id 1BTBQI1_L4nLo7Y41Nr-fx8Z_U7oFDFdA
# title 42, id 1Tz8gP_5HKvb9gwOz2WvnzLe-HMUJbbOg
# title 3d, id 1hYGrLhjeaVrnlRZ8Xl0DlfobDv3mEEuc
# title 51, id 1oE2s7D_CQcwSoRE0udvQ1T9D5vRsAKS-
# title 50, id 1ltS4JH8j8IQlAL_DLWYvFdyNvQ9QiEHn
# title 4a, id 1_0oP8gC8k38TtWnZs6pVWGbJ5Fx8ydl3
# title 48, id 1xC4RG7gk7s7PQoiF8xBoBq6zBVekJdxL
# title 47, id 1MAahVNTCvpj6tjB6aRyslQ9w9bEjgBBJ
# title 3b, id 1MlG6oJNWNN5s_54XIYVnWlrKPMcGbyLg
# title 37, id 1mQAgTxNrvylypKWYK0ARVLTqMoJMvkaE
# title 33, id 1duwbadi-bCZnbMapEa3TkFe8tqEaq7Ja
# title 36, id 1420kzEHhhoVahCkBVvA2iGhVDCrfbEDx
# title 35, id 1n_9RBJ-p7ERRIEoApRMovgXX2OejnZGW
# title 1d, id 1Nqzp6Vsm0uZoftYMbR-pmPH-7feOA7TN
# title 30, id 1mtjL-epxMBDJNElixA1f_tuq-P2n6JaZ
# title 2f, id 1PaQFhnpcg0GDrXgNi5aO0LtuPQUDWTYW
# title 1f, id 1hb5iHhryVdNwHYdSfms5FKA7FCTRLW6-
# title 2d, id 11dEXvxBoWrl0PE7DTdiZ__NTBSrifTuH
# title 1c, id 1dCXRhC_TC5VObWM0AwqwSRZIJ_omQVm0
# title 19, id 1H3dP3H7DKRwt0roshvDNphQFrSihJLaJ
# title 08, id 1tw2vbkvBnORAAIKxCxROxABT1ni4ksMR
# title 0b, id 1bdQ7gttQ8QzJnFHPFEwpy0E2Ky5KyM0z
# title 0f, id 1TmXzQQJhUEuWRbILp6LM3pSFUxqxMW3V
# title commons-math3-3.6.1, id 1L7WUeh0_hgS-HDbkEbBHrGdqtW0FLuYT
# title News Viewer, id 1bYBp9CngyOs3w9jWB5v42b0JJm10KJNR
# title 07, id 1_YAmrd86XNDoWqTH48wm-HBniCEzlxzq
# title refs, id 1fq-zIyqr2QjFDIM1PfinDJziOkQ_lGHL
# title final, id 1ESRsUaImIOwsIsjplQZ5W1LSNKnlS8Jy
# title Fake news detection, id 1wME7ITo6X7ddsML08WahY3K5kMa71cT_
# title tech, id 1OfCMyQPYnZALxAnWckOo_PKW1a3I28dA
# title sport, id 1zIFw9nLszydpcus4tfT4mkWxoH8Wc18c
# title entertainment, id 1eppfMKLm4NuSwO1wSg8pKZVmRARIZKOs
# title politics, id 1G7sOYrxAn17-YfVBB6iSCqdX4NzR0xNs
# title libraries, id 19GyJG4KXIQ7FnzXWzgzX2URSlbjldkP4
# title refs, id 1Ieo-qMgPqIyhAfpR3oTz1W12NDopmQMb
# title logs, id 14Fs4SvSED8VI2YyvtrfcB7w2sEKdhA3i
# title objects, id 15M0G5ENGf5YmhFC8Z5C5tvGsLX3X-DMG
# title commons-math3-3.6.1-bin, id 1LRa5LCsUK2XR3hZGY4q54_vadAYQ7jAt
# title business, id 17ZtbzQiYo2AQBW49qUQmBduq4TVvjIU9
# title production, id 1kFEuUTEilSDaxTW9WNvlYJVaiWsIFK33
# title src, id 1Co28vm3NH1JWzKWIv98jfoyMKj22rsMT
# title src, id 1ezkSeZrsIRLZeaPRhwle7cbq8EqNmWvy
# title fake-news, id 1GtzS8U44KQ4RARYTro58kw-syYlE8AkY
# title hooks, id 1dFbinoGDmKeVBxuNs57OG6jjHN26HChg
# title info, id 1KSLOVGKJwRAD1sE8Wcns_ZpvluWLyesG
# title branches, id 1cO-XudyWI7iUWXAIG5KUT4ZWV2mB9KZE
# title __MACOSX, id 1VhoETSFi6RyUitG8VpV-r_23Hbqnip3A
# title temp, id 1xylHgO7qGjv_poPSx5KghW1puRr_zt-0
# title bbc, id 1BNrIxgCGHDS-sDsEMYTp5TkEEx7zI9Yt
# title src, id 1Qpg98JlsDydcZ3C-phiL6Djjt7-LK_n5
# title politics, id 1hC3t2P2DBk08dbUhEzG1iBgX4ZsOoYdr
# title out, id 19qVzM-kR-2yrRc3bTaU42ZhkI-DYmI71
# title FETCH_HEAD, id 1PXDCMAqzAOgaMZMdIWCYSAMCviteo4Ph
# title config, id 1yw62MFaTL3RhykH-NWQuk54mFlNc2-ys
# title description, id 1UtluI5HTnfnm6KBwtXfWwduXVcDAEopM
# title StANNIE_2.HTML, id 1wTkzAQR8IKAD6TFXELCphIXb-lpvxPBP
# title final, id 1zNH5K2hcFHGjUbxlCYGdJFrnzLUL9aYA
# title lib, id 1wgm8C1mHKI65LBVhuhoSCcNCiSyMu-zj
# title StANNIE_toXML_1.HTML, id 1c29zQqVF4T0JLnZxd864r2eZwi8mC9_N
# title Fake news detection, id 1RrdeP-hRWevIjZ8Lxz-p5fkhixQQYThh
# title StANNIE_1.HTML, id 1uUQxKUQD72O1aO5Vq3T5VD7mQtEnQPGB
# title exportToHTML, id 1ciY6D8Qwbbt3EkmM0xYAuAKe6ZC0Udow
# title datasets, id 1lMAe6ziJL7EWTMLKGnhQhkOqT1e9-aT8
# title .idea, id 1D7JbWAgPuI5Yio3bcBa2JhvNwmtR4EBE
# title .git, id 1Egr2yeTRKEnfXb-VLbNcO5YjGnYdv4gM
# title NewsAggregatorDataset, id 17qrJY1wHG5agEdgRjliy4xzjBYZ4PTRK
# title bbc-fulltext, id 18DGTaxgXV7gZVVKSZUuXOmYjQAaavePz
# title StANNIE_toXML_2.HTML, id 1W5dNLkFF_pBg9oUWOCi_jlxhZeNEwyW7
# title origin, id 1ZMdH2KsPQJPNSyPWYdu6vQb4uCSFqErq
# title bbc, id 18FYoLRrxanUsDydROfauIde6a0Ga4Eyb
# title origin, id 1xGODh3AuBfyRCXh9QhwnXKj7gfxyKSHH
# title TextAnalysisTS.iml, id 1dbUBek9X1lW8CncuGzspophLTzZr8Day
# title ~$CVR-TSL&DistDownloadWithTextFy13-H1Fy18CM.XLSX, id 1Qxt498coZA5JqW_zAJ0Wx-srCDysagWP
# title datasets, id 1Cf4bvY-yVVpCMCgXko_sxZJy0Bfa9Ems
# title heads, id 1_xVeL6RNh2oAY3NxHnFQgDYAO4KEghFQ
# title remotes, id 15QCWfqfgIrci5n8FvfJYJ-BmEpsWCeQ5
# title News Viewer, id 1VycrRUfnJDgWfJIaPIIix9ZO_xSuYgti
# title TextAnalysisTS, id 1RPKezeoODxPytHQA42gSMthyvbAgT367
# title unnamed, id 1AiYJCWgmrkjzYex6Dkzf6mf1WWB2Dz9f
# title tags, id 1gUmVQHRgykwaXX8CgyH_2TeqDJ6pg95O
# title gatePractice, id 1T60iBe672Qqq-4LZRj90NZJjpGTRHybB
# title info, id 1gU5TEEKdQXh4JlYBpeKzzeJn7svb6jzk
# title remotes, id 1_VC4ozfTqTLOZ1P0fgTcjHlPicBBYMrU
# title fd, id 1ZallVg1f7xxw--UcqgBMCMO6-l79jKKG
# title heads, id 1p5crERSwWFCGdBNKDm1ZwX8mq-Ov3DOH
# title f8, id 1VYaSYAXrIPF5yv1hHULeelNOpCqdsRDZ
# title pack, id 1Rs2nNxPfu9X0w1KlyX48VN_7J6-H7VZ7
# title f6, id 1ccL5rVPMhuxeCGjjHfPNqdScWnCgcWpn
# title ed, id 1piCMYSsfQRvHFxHYMJQbnogp4jOuITB2
# title f1, id 1sRcKgWmzypG_BQp2EKC4bqH_D3YFXRFt
# title eb, id 1Auv2w8likYGEujjEnSmQ6NyMUZjctf8S
# title de, id 114KkAKWUSK5UpdEuDKzUoRtOJjMPagJS
# title d7, id 1MNY9Po4zorC6T_0BjmZQ_-MeuFRQwpL8
# title dd, id 1R9kQv9f4bRz19is9zXB0DQ7oQsLXv1fs
# title e6, id 19W4_fz4FHFmkDVT2weZjVbdIzOoKpuHa
# title e8, id 1fOydwanRW3M36gL8L6E8FvHWF__mN0hK
# title e1, id 1ydgI2iHr0J09WHI6IM16hnuXIkznVcDn
# title d6, id 1hGhNjTna14PN5FEpbjOFDQW4kWCNiFOq
# title c8, id 1jViKmeHtPW33miKKS9EOWnh0yvTQHT6z
# title c9, id 1AFWNqqL5ou_Y2aqJHN8qYOobcDbN4bP5
# title bb, id 1wTtXQ_ZkfghdmoEA05CDf7r_aL32a8hj
# title ab, id 1ulXoMt_USWxm3Ek8T-7bBEvfSKaGxt7p
# title ba, id 1FvID8GHcew0ce5Bx0BVItLl4fculhMoI
# title b4, id 1RkUeV1g-Wrsty3nhgB85gmabsfS80pkr
# title b2, id 1u9mjp-zDqdPB_8wUNrHJa5IJpwsN3lt8
# title b1, id 1onxCM4Z0snxH6kWJWNu1ZdblDjLdllQZ
# title b8, id 1W89ZIuSax-RgY37XFW5crDqS7_Kl03hC
# title a2, id 1tcIq_pAP38QCaDJlBXqOXqAcd-uddYRD
# title 99, id 1PMAhrImKSDW_AHUbBnpeVbqJg_n_Xcei
# title aa, id 1qKV11goqFZuYUqVBenVKBleXCX3SfcVM
# title 9f, id 1HWvdGMPO0eWW5FQLN2bjyq7ks5zQ8vtp
# title 89, id 1DYsZcvdeBTFIx3dEbCtIhTamodlDGaWI
# title 8b, id 1aHRQUk6PQbW8xx9J3JYE8PSNd4G6VyKU
# title 97, id 1p_ndeCATflJkaO_mj7WPp7KrV1tbW5Wu
# title 95, id 1CJuMMmZVmQ5exB40BH000K6r8lUGxPd4
# title 91, id 10M-fIiaLBBsUqwyXAFVhJrjM4GAcS5X0
# title 8a, id 19RdWKMWxmQv6M_mhUtnydbYmsfSMDXsb
# title 84, id 1FaBeUaeGSmDb5lbt0pcgpmmV7AWrbKjH
# title 86, id 1CaVR2fVAx-u1k8ZOMyiup_mP2Ouj5m8W
# title 7d, id 1VWUGMOpGsbH0u5s1uQrLYomi-tQTMu_A
# title 7f, id 1rrfmR_ldCUJdQHixnD_4Gz68KJEIQfhX
# title 70, id 1c37mF0dBt19MnJK4kegciPgSfZnTkAz3
# title 6a, id 1k4Iv8Jc_qs06MyLgMhAgLwlAIyMo5woa
# title 72, id 16A3NLF2DsyUW7m8Fn0cw7HekKp_VWYW4
# title 6b, id 1i5er5ux5guBxrTu6QFnHAYW385QDOD1D
# title 69, id 1RJrfycQNoiFtNJfQGMxGCzTs8bzrRRKJ
# title 7b, id 1mjt6mA_xQ7JcktZxpB9WLKzhWLGmNXC9
# title 5d, id 1qUQiwis2zOpN_6FAVHvOCLPeciKWyUud
# title 67, id 1pF8WA1eTFc6-38D1Wu2F5gO82Gz6gC-T
# title 57, id 16fu8M647VW0jyNjGXIOaUNppAhbZ9HEY
# title 59, id 1Zm5Fh9cp7GqdN4q6q36SX-yG4me43_K5
# title 4f, id 10wOor2AzSwe9IOdBGu8AjFwQc2XH2Knh
# title 52, id 16w9n-17tlfpvjPpGMo0rwOc3_37CkFP0
# title 55, id 1_e1xKdKz7Uu65P_1BLhyjNMu5AjjLEtY
# title 40, id 15nuUdsaXqe1vwt67FfGjMHAO5I-oLAK-
# title 47, id 11tDHRnnNsELCUMjuKzH-A1c8-yLH8O4f
# title 4e, id 1e_KSOvYRn73QAnSYkOOFvQDtjlxGW3p4
# title 38, id 1Xdb9c_8-BrlF3PjmGdf6Rd1e2640yClS
# title 3c, id 15Gw9OUkMqOVGgle-CR48_uU_cysZPyfk
# title 3f, id 1OCQFqrIFonSXIkPramtKGL0TkoxeG0US
# title 3d, id 1YsNnbBw75sKkOAUcnD9zihMJufz3AbUC
# title 27, id 12aDXn9tZFykzrWJB8r_8iWN7gcLcQdEk
# title 24, id 1U1vBaZJgjw31qp22AyrF8LA4AkRBcDN6
# title 20, id 1DCwuVOyn_qVFyq2dL-Cld_WSeuWOSZtc
# title 25, id 1Tsr0EOoYe-q8zKhu1-Jt9gmrvyV04ocU
# title 17, id 1-06J5ZkGD7M1iVaEug-wTSGM73UrObZP
# title 1f, id 1YvIiWiEztcw15iZrpDuVR6JMpafg8aCO
# title 1a, id 1U3zxVihITGxBhxbr0jExebr7J4gTyYFx
# title 1b, id 13lylin4afxy-0kCVXqPodvnaasP69YDx
# title StANNIE_2.HTML, id 1a1_-FT0O9v-1DXROEg_ScQfEEFJyWiJh
# title StANNIE_1.HTML, id 1k3dD18YxurL8OhOIzxOexy_ageKkO8-K
# title 11, id 1pYHIPKVglXzvCArCTw6WCtxPn91FVIEo
# title 05, id 1X11WcqhszSW9wHqD4SGVOXMgViP12I99
# title 13, id 1he4EQnhUEehj_DaPLfoZ5KOdNCebpIrW
# title 06, id 1F0B4Fhpud9fbfyC0eElE2d4sPlXM2GoI
# title 02, id 1AituA_LqoMDlfajpBmFAkA4W1vLDZS2B
# title refs, id 1c8BMNa5r4WFwgGT8qYC01Y9QwZEN1H5d
# title 00, id 1k3wncA_q6lCYcaOZSsQERSo5O_K4sSgt
# title production, id 1rjzVSQJdWLh30p0zLgBMj28pdzmvEOll
# title libraries, id 1vl9IK0I3wbfR8wla0OPu7iYAOGtEeDRp
# title src, id 1iU3uQ_Y8thlIr5tHzD7eMb3LFYfRY1bK
# title shelf, id 1mK2C9gB_V8JdWAE4Tfd3iOqZc3d0VRry
# title refs, id 1lN4W3Ym08wB3N_cZkWfEefHU-EIB8I8k
# title logs, id 1NZkxqDltkGFIMzKsmvb_36Bf1MnSl-gc
# title info, id 1w3sqlC_GnQYrFLvZf9Fwv9XzoF1-zkHx
# title objects, id 12sKlIrUj63oJUcMf-9pXrRwkT0-egUQ8
# title hooks, id 1hySK6KjzfQE2z4gck5DAxoRRQDE1wNAn
# title demo.txt, id 14rnQy3dHpzVGBr0ZHT-X6fDaSpvR1Low
# title README.md, id 1u3TxVCuLs-qi2YAaPsXJiu2nH-2zKGGG
# title notes.txt, id 1QpmtMkfhjH_e2nr8yfF8RA7T0qSeoyCI
# title CVR-TSL&DistDownloadWithTextFy13-H1Fy18CM.csv, id 1EZoIx9sCaHAPetkhtrqYT6uCbTXTjKMv
# title .idea, id 1UoMoIhIRxMEmHrKGgSc_2NxgrxPyFQOn
# title gatePractice, id 1BGUtYJuff0U6tlt1-Xn_glT4DMgQ7X8l
# title .git, id 1tuw4b8wuRbGVre0u0Xyh8tdfAHBo3eiH
# title src, id 1-OJB-jkFAa5tA6EcAkt8ggH0wfRil_5o
# title japes, id 1yDTHREiF-izZ1cwEhGQgwAoQ6uLa1dDj
# title out, id 1Xun66kz4c1YtCo8tKxl_T7WbH3NLSe6a
# title TextAnalysisTS, id 1vkA_6PQeZDdZzmDi4IbuPqR7LpMC9QEu
# title Getting started, id 0B6BKp6MQ-aSIc3RhcnRlcl9maWxlX2Rhc2hlclYw

# %%
downloaded = drive.CreateFile({'id': '11j1LyGLuq-HIHEgPNlzcxg0pO57rBA2y'})
downloaded.GetContentFile('train.zip')
with ZipFile("train.zip", 'r') as z:
    z.extractall()
os.remove("train.zip")

# %%
class TGSSaltTrainDataset(Dataset):
    def __init__(self, image_dir,mask_dir,depth_csv,train_csv):
        self.image_dir=image_dir
        self.mask_dir=mask_dir
        
#         depth=pd.read_csv(depth_csv)
#         depth["z"]=(depth["z"]-depth["z"].min())/(depth["z"].max()-depth["z"].min())
        self.filter = np.array([(0,-1,-1,-1),(1,0,0,0),(1,0,1,0),(0,1,0,1)])/8
        self.input = pd.read_csv(train_csv)
        self.input['z'] = (self.input['z']-self.input['z'].min())/(self.input['z'].max()-self.input['z'].min())
        self.input.drop(['rle_mask'],axis=1,inplace=True)
#         self.input = self.input.merge(depth,how="left",on="id")
        
        
    def __len__(self):
        return len(self.input)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir,self.input.iloc[idx,0]+".png")
        img = cv2.imread(img_name)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

        img = torch.tensor(img).view(101,101).float()
      
        mask_name = os.path.join(self.mask_dir,self.input.iloc[idx,0]+".png")
        mask = cv2.imread(mask_name)
        mask = cv2.cvtColor(mask,cv2.COLOR_BGR2GRAY)
        mask = torch.tensor(mask).float()/255
        depth = self.input.iloc[idx,1].reshape(1)
        return img,mask,depth

# %%
train_dataset = TGSSaltTrainDataset("train/images","train/masks","depths.csv","train.csv")

# %%
train_dataset.input = train_dataset.input[:200]

# %%
def save_checkpoint(state, filename='checkpoint.pth.tar'):
    torch.save(state, filename)
    uploaded = drive.CreateFile({'title': 'TGSUNet_epoch'+str(state['epoch'])+'.pt'})
    uploaded.SetContentFile(filename)
    uploaded.Upload()
def load_checkpoint(args):
     
    if os.path.isfile(args):
        print("=> loading checkpoint '{}'".format(args))
        checkpoint = torch.load(args)
        epoch = checkpoint['epoch']
        model.load_state_dict(checkpoint['state_dict'])
        optimizer.load_state_dict(checkpoint['optimizer'])
        print("=> loaded checkpoint '{}' (epoch {})"
              .format(args, checkpoint['epoch']))
    else:
        print("=> no checkpoint found at '{}'".format(args.resume))

# %%
class double_conv(nn.Module):
    '''(conv => BN => ReLU) * 2'''
    def __init__(self, in_ch, out_ch):
        super(double_conv, self).__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm2d(out_ch),
            nn.ReLU(inplace=True),
            nn.Dropout2d(p=0.0)
        )

    def forward(self, x):
        x = self.conv(x)
        return x


class inconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(inconv, self).__init__()
        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x):
        x = self.conv(x)
        return x


class down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(down, self).__init__()
        self.mpconv = nn.Sequential(
            nn.MaxPool2d(2),
            double_conv(in_ch, out_ch)
        )

    def forward(self, x):
        x = self.mpconv(x)
        return x


class up(nn.Module):
    def __init__(self, in_ch, out_ch, bilinear=True,up_size=None,padding=None):
        super(up, self).__init__()

        #  would be a nice idea if the upsampling could be learned too,
        #  but my machine do not have enough memory to handle all those weights
        if bilinear:
            if up_size:
                self.up = nn.Upsample(size= up_size, mode='bilinear', align_corners=True)
            else:
                self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        else:
            if padding:
                self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2,output_padding=padding)
            else:
                self.up = nn.ConvTranspose2d(in_ch//2, in_ch//2, 2, stride=2)

        self.conv = double_conv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffX = x1.size()[2] - x2.size()[2]
        diffY = x1.size()[3] - x2.size()[3]
        x2 = F.pad(x2, (diffX // 2 , int(diffX / 2),
                        diffY // 2, int(diffY / 2)))
        x = torch.cat([x2, x1], dim=1)
        x = self.conv(x)
        return x



class outconv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super(outconv, self).__init__()
        self.conv = nn.Conv2d(in_ch, out_ch, 1)

    def forward(self, x):
        x = self.conv(x)
        return x
class conv3d(nn.Module):
    '''
    Takes a image with given number of channels and performs 3d convolution and then returns the image as 2d
    '''
    def __init__(self):
        super(conv3d, self).__init__()
        self.conv1 = nn.Conv3d(1, 4, 2,stride=2,padding=1)
        self.conv2 = nn.Conv3d(4, 16 ,4,stride=2,padding=1)

    def forward(self, x):
        x.unsqueeze_(1)
        x = self.conv1(x)
        x = self.conv2(x)
        x = x.view(-1,512,6,6)
        return x

class DN(nn.Module):
    '''
    @IN
    img: A tensor representing the grayscaled image; shape:[batch_size,1,101,101]
    d: The z index of the image
    
    @OUT
    shape:[batch_size,1,101,101] tensor representing the features found by kernel(3*3) created from depth value
    '''
    def __init__(self):
        super(DN,self).__init__()
        self.layer1 = nn.Sequential(nn.Linear(4,9,bias=False),
                                   nn.ReLU())
        self.layer2 = nn.Sequential(nn.Linear(9,9,bias=True),
                                   nn.Sigmoid())
        self.conv1 = nn.Conv2d(1,1,kernel_size=3,stride=1,padding=1,bias=False)
        self.non_linear1 = nn.ReLU()
    def forward(self,x,d):
        d= d.view(1)
        ker = torch.tensor([d,d**2,d**3,1]).float().cuda()
#         print(ker)
        ker = self.layer1(ker)
        ker = self.layer2(ker).view(1,1,3,3)
        self.conv1.weight = nn.Parameter(ker)
        x = self.non_linear1(self.conv1(x))
        return x
class UNet(nn.Module):
    def __init__(self,debug=False):
        super(UNet, self).__init__()
        self.debug = debug
        self.inc = inconv(1, 64)
        self.down1 = down(64, 128)
        self.down2 = down(128, 256)
        self.down3 = down(256, 512)
        self.down4 = down(512, 512)
        self.up1 = up(1024, 256,up_size = (12,12),bilinear=False)
        self.up2 = up(512, 128,up_size = (25,25))
        self.up3 = up(256, 64,up_size = (50,50),bilinear=False)
        self.up4 = up(128, 64,up_size = (101,101))
        self.outc = outconv(64, 1)

    def forward(self, x):
        x.unsqueeze_(1)
        if self.debug: print(x.shape)
        x1 = self.inc(x)
        if self.debug: print(x1.shape)
        x2 = self.down1(x1)
        if self.debug: print(x2.shape)
        x3 = self.down2(x2)
        if self.debug: print(x3.shape)
        x4 = self.down3(x3)
        if self.debug: print(x4.shape)
        x5 = self.down4(x4)
        if self.debug: print(x5.shape)
        if self.debug: print('before up')
        x = self.up1(x5, x4)
        if self.debug: print(x.shape)
        x = self.up2(x, x3)
        if self.debug: print(x.shape)
        x = self.up3(x, x2)
        if self.debug: print(x.shape)
        x = self.up4(x, x1)
        if self.debug: print(x.shape)
        x = self.outc(x)
        if self.debug: print(x.shape)
        return x.squeeze(1)

# %%
class UDNet(nn.Module):
    def __init__(self,debug=False):
        super(UDNet,self).__init__()
#         self.dn = DN()
        self.un1 = UNet(debug=debug)
        self.un2 = UNet(debug=debug)
    def forward(self,x,d):
        x = self.un1(x)
#         x.unsqueeze_(1)
#         x = self.dn(x,d)
#         x.squeeze_(1)
        x = self.un2(x)
        return x

# %%
model = UDNet(debug=False).cuda()
x = torch.randn(10,101,101).cuda()
print(model(x,torch.tensor(train_dataset[1][2][0])).shape)

# %%
batch_size = 20
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size)
validation_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size)

# %%
batch_size = 20
validation_split = 0.1
shuffle_dataset = True
random_seed= 42
# Creating data indices for training and validation splits:
dataset_size = len(train_dataset)
indices = list(range(dataset_size))
split = int(np.floor(validation_split * dataset_size))
if shuffle_dataset :
    np.random.seed(random_seed)
    np.random.shuffle(indices)
train_indices, val_indices = indices[split:], indices[:split]

# Creating PT data samplers and loaders:
train_sampler = SubsetRandomSampler(train_indices)
validation_sampler = SubsetRandomSampler(val_indices)
train_loader = torch.utils.data.DataLoader(train_dataset,batch_size=batch_size,sampler=train_sampler)
validation_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size,sampler=validation_sampler)

# %%
class BinaryCrossEntropyLoss2d(nn.Module):
    def __init__(self, weight=None, size_average=True):
        """
        Binary cross entropy loss 2D
        Args:
            weight:
            size_average:
        """
        super(BinaryCrossEntropyLoss2d, self).__init__()
        self.bce_loss = nn.BCELoss(weight, size_average)
        if torch.cuda.is_available():
            self.bce_loss = self.bce_loss.cuda()
        self.threshold = torch.tensor(0.3,requires_grad=True).cuda()

    def forward(self, pred, target):
#         pred = F.sigmoid(pred)
        threshold=0.3
        pred1 = ((pred>(1-self.threshold)) * (pred<(1+self.threshold))).float().cuda()
        pred1 = pred1.view(-1)  # Flatten
        target = target.view(-1)  # Flatten
        return self.bce_loss(pred1, target)

# %%
class SoftDiceLoss(nn.Module):
    def __init__(self):
        super(SoftDiceLoss, self).__init__()
    def forward(self, pred, target):
        smooth = 1
        num = target.size(0)
        #pred = F.sigmoid(pred)
        pred = pred.view(num, -1)
        target = target.view(num, -1)
        intersection = (pred * target)
        score = 2. * (intersection.sum(1) + smooth) / (pred.sum(1) + target.sum(1) + smooth)
        score = 1 - score.sum() / num
        return score

# %%
def dice_coeff(pred, target):
    smooth = 1.
    num = target.size(0)
    pred = pred.view(num, -1)  # Flatten
    target = target.view(num, -1)  # Flatten
    intersection = (pred * target)
    score = (2. * intersection.sum(1) + smooth).float() / (pred.sum(1) + target.sum(1) + smooth).float()
    return score.sum()/num

# %%
def bce_dice_loss(y_true, y_pred):
    return 0.5*BinaryCrossEntropyLoss2d()(y_true, y_pred)-dice_coeff(y_true, y_pred)

# %%
model=UDNet()
criterion =nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=0.1)
# exp_lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, step_size=100, gamma=0.1)
if torch.cuda.is_available():
    model = model.cuda()

# %%
def validate(threshold):
    total_loss = 0
    accuracy = 0
    model.eval()
    for batch_idx, (data,target,d) in enumerate(validation_loader):
        if torch.cuda.is_available():
            data = data.cuda()
            target = target.cuda()
        # forward
        output = model(data,d)
        predict = ((output>(1-threshold)) * (output<(1+threshold))).float()
        # backward + optimize
        loss = criterion(predict, target)
        # print statistics
        accuracy += dice_coeff(predict, target).item()
        total_loss+=loss.item()
    print('Validation Loss: {:.5f} Validation Accuracy: {:.5f}'.format(total_loss*batch_size/len(val_indices),accuracy*batch_size/len(val_indices)))

# %%
# %matplotlib inline
from IPython.display import clear_output

def train(threshold,epoch=1):
    
    
#     yyy = []
#     h1, = plt.plot(range(len(yyy)), yyy)
#     plt.rcParams["figure.figsize"] = [20,8]
#     plt.show()
    while True:
        if epoch%5==1:
            save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),
            },filename='model_state'+str(epoch)+'.tar')
        total_loss = 0
        total_accuracy = 0
        model.train()
        if epoch == 40:
            adjust_learning_rate(optimizer,0.01)
        if epoch == 100:
            adjust_learning_rate(optimizer,0.001)
        if epoch == 150:
            torch.save(model,'TGSUNetsimple231.pt')
            uploaded = drive.CreateFile({'title': 'TGSUNetsimple231.pt'})
            uploaded.SetContentFile('TGSUNetsimple231.pt')
            uploaded.Upload()
#         adjust_learning_rate(optimizer,0.01)
#         exp_lr_scheduler.step()
#         print(exp_lr_scheduler.get_lr())
        for batch_idx, (data,target,d) in enumerate(train_loader):
            if torch.cuda.is_available():
                data = data.cuda()
                target = target.cuda()
            # forward
            output = model(data,d)
            predict = ((output>(1-threshold)) * (output<(1+threshold))).float()
            # backward + optimize
            loss = criterion(output, target)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            # print statistics
            accuracy = dice_coeff(predict, target)
            
#             plt.show()
            total_accuracy+=accuracy
            total_loss+=loss
            if batch_idx%5 == 0:
#                 yyy.append(accuracy)
#                 clear_output(wait=False)
#                 h1, = plt.plot(range(len(yyy)), yyy)
#                 plt.show()
                print('Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.5f}\tAccuracy: {:.5f}'.format(epoch, (batch_idx + 1) * len(data), len(train_indices),100*(batch_idx + 1)* len(data) / len(train_indices), loss.item(),accuracy))
#                 print(str(batch_idx/len(train_indices)*100)+'% completed')
    
#              print('Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.5f}\tAccuracy: {:.5f}'.format(epoch, (batch_idx + 1) * len(data), len(train_indices),100*(batch_idx + 1)* len(data) / len(train_indices), total_loss.item(),accuracy))
        print('Epoch: {} Train Loss: {:.5f} Train Accuracy: {:.5f}'.format(epoch,total_loss.item()*batch_size/len(train_dataset),total_accuracy.item()*batch_size/len(train_dataset)))
        validate(threshold)
        epoch+=1

# %%
model.cuda()
train(0.2,epoch=26)
# Out:
# Epoch: 26 [20/14400 (0%)]	Loss: 0.03535	Accuracy: 0.80295
# Epoch: 26 [120/14400 (1%)]	Loss: 0.01699	Accuracy: 0.83209
# Epoch: 26 [220/14400 (2%)]	Loss: 0.03254	Accuracy: 0.92040
# Epoch: 26 [320/14400 (2%)]	Loss: 0.02032	Accuracy: 0.78774
# Epoch: 26 [420/14400 (3%)]	Loss: 0.01489	Accuracy: 0.85219
# Epoch: 26 [520/14400 (4%)]	Loss: 0.03985	Accuracy: 0.60858
# Epoch: 26 [620/14400 (4%)]	Loss: 0.02524	Accuracy: 0.88739
# Epoch: 26 [720/14400 (5%)]	Loss: 0.01516	Accuracy: 0.86259
# Epoch: 26 [820/14400 (6%)]	Loss: 0.01513	Accuracy: 0.84075
# Epoch: 26 [920/14400 (6%)]	Loss: 0.10179	Accuracy: 0.78009
# Epoch: 26 [1020/14400 (7%)]	Loss: 0.01900	Accuracy: 0.68111
# Epoch: 26 [1120/14400 (8%)]	Loss: 0.07802	Accuracy: 0.67138
# Epoch: 26 [1220/14400 (8%)]	Loss: 0.02385	Accuracy: 0.80496
# Epoch: 26 [1320/14400 (9%)]	Loss: 0.02303	Accuracy: 0.88514
# Epoch: 26 [1420/14400 (10%)]	Loss: 0.02485	Accuracy: 0.79180
# Epoch: 26 [1520/14400 (11%)]	Loss: 0.05244	Accuracy: 0.69678
# Epoch: 26 [1620/14400 (11%)]	Loss: 0.02125	Accuracy: 0.78978
# Epoch: 26 [1720/14400 (12%)]	Loss: 0.03275	Accuracy: 0.78927
# Epoch: 26 [1820/14400 (13%)]	Loss: 0.03254	Accuracy: 0.70951
# Epoch: 26 [1920/14400 (13%)]	Loss: 0.06229	Accuracy: 0.77806
# Epoch: 26 [2020/14400 (14%)]	Loss: 0.03300	Accuracy: 0.79697
# Epoch: 26 [2120/14400 (15%)]	Loss: 0.03161	Accuracy: 0.77849
# Epoch: 26 [2220/14400 (15%)]	Loss: 0.03756	Accuracy: 0.62449
# Epoch: 26 [2320/14400 (16%)]	Loss: 0.01053	Accuracy: 0.85932
# Epoch: 26 [2420/14400 (17%)]	Loss: 0.04051	Accuracy: 0.65046
# Epoch: 26 [2520/14400 (18%)]	Loss: 0.01895	Accuracy: 0.78555
# Epoch: 26 [2620/14400 (18%)]	Loss: 0.02123	Accuracy: 0.85423
# Epoch: 26 [2720/14400 (19%)]	Loss: 0.03301	Accuracy: 0.81529
# Epoch: 26 [2820/14400 (20%)]	Loss: 0.03248	Accuracy: 0.81305
# Epoch: 26 [2920/14400 (20%)]	Loss: 0.01534	Accuracy: 0.87840
# Epoch: 26 [3020/14400 (21%)]	Loss: 0.01726	Accuracy: 0.86121
# Epoch: 26 [3120/14400 (22%)]	Loss: 0.03065	Accuracy: 0.75868
# Epoch: 26 [3220/14400 (22%)]	Loss: 0.02530	Accuracy: 0.87567
# Epoch: 26 [3320/14400 (23%)]	Loss: 0.01527	Accuracy: 0.93761
# Epoch: 26 [3420/14400 (24%)]	Loss: 0.02930	Accuracy: 0.72657
# Epoch: 26 [3520/14400 (24%)]	Loss: 0.03127	Accuracy: 0.85802
# Epoch: 26 [3620/14400 (25%)]	Loss: 0.01289	Accuracy: 0.82724
# Epoch: 26 [3720/14400 (26%)]	Loss: 0.02630	Accuracy: 0.70289
# Epoch: 26 [3820/14400 (27%)]	Loss: 0.02541	Accuracy: 0.87477
# Epoch: 26 [3920/14400 (27%)]	Loss: 0.01227	Accuracy: 0.82385
# Epoch: 26 [4020/14400 (28%)]	Loss: 0.03694	Accuracy: 0.86354
# Epoch: 26 [4120/14400 (29%)]	Loss: 0.02514	Accuracy: 0.85791
# Epoch: 26 [4220/14400 (29%)]	Loss: 0.01908	Accuracy: 0.83560
# Epoch: 26 [4320/14400 (30%)]	Loss: 0.03427	Accuracy: 0.68192
# Epoch: 26 [4420/14400 (31%)]	Loss: 0.01254	Accuracy: 0.80982
# Epoch: 26 [4520/14400 (31%)]	Loss: 0.02835	Accuracy: 0.65836
# Epoch: 26 [4620/14400 (32%)]	Loss: 0.01168	Accuracy: 0.82583
# Epoch: 26 [4720/14400 (33%)]	Loss: 0.01561	Accuracy: 0.85075
# Epoch: 26 [4820/14400 (33%)]	Loss: 0.02752	Accuracy: 0.58376
# Epoch: 26 [4920/14400 (34%)]	Loss: 0.01415	Accuracy: 0.95149
# Epoch: 26 [5020/14400 (35%)]	Loss: 0.07930	Accuracy: 0.73502
# Epoch: 26 [5120/14400 (36%)]	Loss: 0.04333	Accuracy: 0.75736
# Epoch: 26 [5220/14400 (36%)]	Loss: 0.03162	Accuracy: 0.75465
# Epoch: 26 [5320/14400 (37%)]	Loss: 0.01496	Accuracy: 0.87736
# Epoch: 26 [5420/14400 (38%)]	Loss: 0.02746	Accuracy: 0.76596
# Epoch: 26 [5520/14400 (38%)]	Loss: 0.01056	Accuracy: 0.88905
# Epoch: 26 [5620/14400 (39%)]	Loss: 0.04252	Accuracy: 0.80044
# Epoch: 26 [5720/14400 (40%)]	Loss: 0.03560	Accuracy: 0.84495
# Epoch: 26 [5820/14400 (40%)]	Loss: 0.05931	Accuracy: 0.76520
# Epoch: 26 [5920/14400 (41%)]	Loss: 0.02801	Accuracy: 0.89917
# Epoch: 26 [6020/14400 (42%)]	Loss: 0.02873	Accuracy: 0.65495
# Epoch: 26 [6120/14400 (42%)]	Loss: 0.01434	Accuracy: 0.86311
# Epoch: 26 [6220/14400 (43%)]	Loss: 0.07580	Accuracy: 0.78103
# Epoch: 26 [6320/14400 (44%)]	Loss: 0.02284	Accuracy: 0.83607
# Epoch: 26 [6420/14400 (45%)]	Loss: 0.03357	Accuracy: 0.78336
# Epoch: 26 [6520/14400 (45%)]	Loss: 0.04050	Accuracy: 0.60708
# Epoch: 26 [6620/14400 (46%)]	Loss: 0.00956	Accuracy: 0.97346
# Epoch: 26 [6720/14400 (47%)]	Loss: 0.03276	Accuracy: 0.69854
# Epoch: 26 [6820/14400 (47%)]	Loss: 0.02122	Accuracy: 0.89930
# Epoch: 26 [6920/14400 (48%)]	Loss: 0.02197	Accuracy: 0.86197
# Epoch: 26 [7020/14400 (49%)]	Loss: 0.03278	Accuracy: 0.83104
# Epoch: 26 [7120/14400 (49%)]	Loss: 0.01866	Accuracy: 0.87590
# Epoch: 26 [7220/14400 (50%)]	Loss: 0.03839	Accuracy: 0.76786
# Epoch: 26 [7320/14400 (51%)]	Loss: 0.02611	Accuracy: 0.78076
# Epoch: 26 [7420/14400 (52%)]	Loss: 0.01929	Accuracy: 0.84426
# Epoch: 26 [7520/14400 (52%)]	Loss: 0.07292	Accuracy: 0.78754
# Epoch: 26 [7620/14400 (53%)]	Loss: 0.01408	Accuracy: 0.91985
# Epoch: 26 [7720/14400 (54%)]	Loss: 0.06495	Accuracy: 0.72976
# Epoch: 26 [7820/14400 (54%)]	Loss: 0.03406	Accuracy: 0.84675
# Epoch: 26 [7920/14400 (55%)]	Loss: 0.01174	Accuracy: 0.83571
# Epoch: 26 [8020/14400 (56%)]	Loss: 0.02697	Accuracy: 0.88733
# Epoch: 26 [8120/14400 (56%)]	Loss: 0.02505	Accuracy: 0.75083
# Epoch: 26 [8220/14400 (57%)]	Loss: 0.01488	Accuracy: 0.76514
# Epoch: 26 [8320/14400 (58%)]	Loss: 0.04199	Accuracy: 0.77963
# Epoch: 26 [8420/14400 (58%)]	Loss: 0.05340	Accuracy: 0.76348
# Epoch: 26 [8520/14400 (59%)]	Loss: 0.02661	Accuracy: 0.80995
# Epoch: 26 [8620/14400 (60%)]	Loss: 0.02638	Accuracy: 0.86453
# Epoch: 26 [8720/14400 (61%)]	Loss: 0.02014	Accuracy: 0.92997
# Epoch: 26 [8820/14400 (61%)]	Loss: 0.01759	Accuracy: 0.75667
# Epoch: 26 [8920/14400 (62%)]	Loss: 0.03476	Accuracy: 0.81039
# Epoch: 26 [9020/14400 (63%)]	Loss: 0.03860	Accuracy: 0.84892
# Epoch: 26 [9120/14400 (63%)]	Loss: 0.03824	Accuracy: 0.85348
# Epoch: 26 [9220/14400 (64%)]	Loss: 0.00645	Accuracy: 0.99142
# Epoch: 26 [9320/14400 (65%)]	Loss: 0.01835	Accuracy: 0.89752
# Epoch: 26 [9420/14400 (65%)]	Loss: 0.01426	Accuracy: 0.83923
# Epoch: 26 [9520/14400 (66%)]	Loss: 0.01508	Accuracy: 0.85946
# Epoch: 26 [9620/14400 (67%)]	Loss: 0.02697	Accuracy: 0.78686
# Epoch: 26 [9720/14400 (68%)]	Loss: 0.01688	Accuracy: 0.89116
# Epoch: 26 [9820/14400 (68%)]	Loss: 0.02345	Accuracy: 0.84471
# Epoch: 26 [9920/14400 (69%)]	Loss: 0.02075	Accuracy: 0.76201
# Epoch: 26 [10020/14400 (70%)]	Loss: 0.06399	Accuracy: 0.73397
# Epoch: 26 [10120/14400 (70%)]	Loss: 0.01222	Accuracy: 0.83949
# Epoch: 26 [10220/14400 (71%)]	Loss: 0.02021	Accuracy: 0.64206
# Epoch: 26 [10320/14400 (72%)]	Loss: 0.02678	Accuracy: 0.68405
# Epoch: 26 [10420/14400 (72%)]	Loss: 0.02144	Accuracy: 0.87391
# Epoch: 26 [10520/14400 (73%)]	Loss: 0.02578	Accuracy: 0.80206
# Epoch: 26 [10620/14400 (74%)]	Loss: 0.02307	Accuracy: 0.92773
# Epoch: 26 [10720/14400 (74%)]	Loss: 0.02978	Accuracy: 0.78255
# Epoch: 26 [10820/14400 (75%)]	Loss: 0.02751	Accuracy: 0.76584
# Epoch: 26 [10920/14400 (76%)]	Loss: 0.02845	Accuracy: 0.77426
# Epoch: 26 [11020/14400 (77%)]	Loss: 0.06792	Accuracy: 0.83594
# Epoch: 26 [11120/14400 (77%)]	Loss: 0.05755	Accuracy: 0.79995
# Epoch: 26 [11220/14400 (78%)]	Loss: 0.02507	Accuracy: 0.71699
# Epoch: 26 [11320/14400 (79%)]	Loss: 0.02738	Accuracy: 0.91797
# Epoch: 26 [11420/14400 (79%)]	Loss: 0.02649	Accuracy: 0.71621
# Epoch: 26 [11520/14400 (80%)]	Loss: 0.01481	Accuracy: 0.80704
# Epoch: 26 [11620/14400 (81%)]	Loss: 0.05841	Accuracy: 0.76188
# Epoch: 26 [11720/14400 (81%)]	Loss: 0.03523	Accuracy: 0.89255
# Epoch: 26 [11820/14400 (82%)]	Loss: 0.04165	Accuracy: 0.75840
# Epoch: 26 [11920/14400 (83%)]	Loss: 0.03050	Accuracy: 0.74012
# Epoch: 26 [12020/14400 (83%)]	Loss: 0.02956	Accuracy: 0.78459
# Epoch: 26 [12120/14400 (84%)]	Loss: 0.01702	Accuracy: 0.92840
# Epoch: 26 [12220/14400 (85%)]	Loss: 0.02933	Accuracy: 0.66655
# Epoch: 26 [12320/14400 (86%)]	Loss: 0.06142	Accuracy: 0.66600
# Epoch: 26 [12420/14400 (86%)]	Loss: 0.02666	Accuracy: 0.82233
# Epoch: 26 [12520/14400 (87%)]	Loss: 0.03283	Accuracy: 0.87706
# Epoch: 26 [12620/14400 (88%)]	Loss: 0.02838	Accuracy: 0.83638
# Epoch: 26 [12720/14400 (88%)]	Loss: 0.01347	Accuracy: 0.90723
# Epoch: 26 [12820/14400 (89%)]	Loss: 0.04489	Accuracy: 0.84022
# Epoch: 26 [12920/14400 (90%)]	Loss: 0.05178	Accuracy: 0.70697
# Epoch: 26 [13020/14400 (90%)]	Loss: 0.03059	Accuracy: 0.72198
# Epoch: 26 [13120/14400 (91%)]	Loss: 0.02574	Accuracy: 0.87550
# Epoch: 26 [13220/14400 (92%)]	Loss: 0.02793	Accuracy: 0.86253
# Epoch: 26 [13320/14400 (92%)]	Loss: 0.06276	Accuracy: 0.64499
# Epoch: 26 [13420/14400 (93%)]	Loss: 0.02272	Accuracy: 0.86345
# Epoch: 26 [13520/14400 (94%)]	Loss: 0.07022	Accuracy: 0.75745
# Epoch: 26 [13620/14400 (95%)]	Loss: 0.04417	Accuracy: 0.75659
# Epoch: 26 [13720/14400 (95%)]	Loss: 0.02003	Accuracy: 0.85218
# Epoch: 26 [13820/14400 (96%)]	Loss: 0.02910	Accuracy: 0.90064
# Epoch: 26 [13920/14400 (97%)]	Loss: 0.03026	Accuracy: 0.80425
# Epoch: 26 [14020/14400 (97%)]	Loss: 0.07327	Accuracy: 0.77486
# Epoch: 26 [14120/14400 (98%)]	Loss: 0.01472	Accuracy: 0.86984
# Epoch: 26 [14220/14400 (99%)]	Loss: 0.02868	Accuracy: 0.82280
# Epoch: 26 [14320/14400 (99%)]	Loss: 0.02144	Accuracy: 0.89273
# Epoch: 26 Train Loss: 0.02888 Train Accuracy: 0.72592
# Validation Loss: 0.06192 Validation Accuracy: 0.78393
# Epoch: 27 [20/14400 (0%)]	Loss: 0.04369	Accuracy: 0.85394
# Epoch: 27 [120/14400 (1%)]	Loss: 0.07680	Accuracy: 0.80677
# Epoch: 27 [220/14400 (2%)]	Loss: 0.02089	Accuracy: 0.88429
# Epoch: 27 [320/14400 (2%)]	Loss: 0.01991	Accuracy: 0.84954
# Epoch: 27 [420/14400 (3%)]	Loss: 0.05235	Accuracy: 0.80273
# Epoch: 27 [520/14400 (4%)]	Loss: 0.02522	Accuracy: 0.87440
# Epoch: 27 [620/14400 (4%)]	Loss: 0.01066	Accuracy: 0.81661
# Epoch: 27 [720/14400 (5%)]	Loss: 0.02860	Accuracy: 0.80678
# Epoch: 27 [820/14400 (6%)]	Loss: 0.02008	Accuracy: 0.85761
# Epoch: 27 [920/14400 (6%)]	Loss: 0.00940	Accuracy: 0.92129
# Epoch: 27 [1020/14400 (7%)]	Loss: 0.06423	Accuracy: 0.70414
# Epoch: 27 [1120/14400 (8%)]	Loss: 0.06157	Accuracy: 0.73439
# Epoch: 27 [1220/14400 (8%)]	Loss: 0.02686	Accuracy: 0.82104
# Epoch: 27 [1320/14400 (9%)]	Loss: 0.03771	Accuracy: 0.78099
# Epoch: 27 [1420/14400 (10%)]	Loss: 0.03887	Accuracy: 0.67029
# Epoch: 27 [1520/14400 (11%)]	Loss: 0.02791	Accuracy: 0.87834
# Epoch: 27 [1620/14400 (11%)]	Loss: 0.02787	Accuracy: 0.75640
# Epoch: 27 [1720/14400 (12%)]	Loss: 0.04291	Accuracy: 0.85757
# Epoch: 27 [1820/14400 (13%)]	Loss: 0.01771	Accuracy: 0.88050
# Epoch: 27 [1920/14400 (13%)]	Loss: 0.08636	Accuracy: 0.64690
# Epoch: 27 [2020/14400 (14%)]	Loss: 0.02243	Accuracy: 0.88970
# Epoch: 27 [2120/14400 (15%)]	Loss: 0.06763	Accuracy: 0.76186
# Epoch: 27 [2220/14400 (15%)]	Loss: 0.01407	Accuracy: 0.88087
# Epoch: 27 [2320/14400 (16%)]	Loss: 0.01045	Accuracy: 0.78080
# Epoch: 27 [2420/14400 (17%)]	Loss: 0.02752	Accuracy: 0.79298
# Epoch: 27 [2520/14400 (18%)]	Loss: 0.02049	Accuracy: 0.86884
# Epoch: 27 [2620/14400 (18%)]	Loss: 0.02889	Accuracy: 0.77984
# Epoch: 27 [2720/14400 (19%)]	Loss: 0.02226	Accuracy: 0.88683
# Epoch: 27 [2820/14400 (20%)]	Loss: 0.04212	Accuracy: 0.75053
# Epoch: 27 [2920/14400 (20%)]	Loss: 0.01541	Accuracy: 0.87994
# Epoch: 27 [3020/14400 (21%)]	Loss: 0.03392	Accuracy: 0.74454
# Epoch: 27 [3120/14400 (22%)]	Loss: 0.02871	Accuracy: 0.82290
# Epoch: 27 [3220/14400 (22%)]	Loss: 0.01697	Accuracy: 0.82368
# Epoch: 27 [3320/14400 (23%)]	Loss: 0.05391	Accuracy: 0.78054
# Epoch: 27 [3420/14400 (24%)]	Loss: 0.05941	Accuracy: 0.72024
# Epoch: 27 [3520/14400 (24%)]	Loss: 0.05662	Accuracy: 0.76171
# Epoch: 27 [3620/14400 (25%)]	Loss: 0.02482	Accuracy: 0.67989

# %%
 save_checkpoint({
            'epoch': epoch + 1,
            'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),
            })
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-82eaed3ba798> in <module>()
#       1 save_checkpoint({
# ----> 2            'epoch': epoch + 1,
#       3            'state_dict': model.state_dict(),
#       4            'optimizer' : optimizer.state_dict(),
#       5            })
#
# NameError: name 'epoch' is not defined

# %%
def adjust_learning_rate(optimizerr,lr):
   
    for param_group in optimizerr.param_groups:
        param_group['lr'] = lr

# %%
save_checkpoint({
            'epoch': 6 + 1,
            'state_dict': model.state_dict(),
            'optimizer' : optimizer.state_dict(),
            },filename='model_state'+str(6)+'.tar')

# %%
downloaded = drive.CreateFile({'id': '150_ntQpNGlPdrwUXA7-cAlzN_CB1pjzX'})
downloaded.GetContentFile('model.tar')

# %%
load_checkpoint('model.tar')
# Out:
# => loading checkpoint 'model.tar'
# => loaded checkpoint 'model.tar' (epoch 22)

# %%
model.cpu()
threshold=0.5
fig, axeslist = plt.subplots(ncols=3,nrows=1)

x,y,d =train_dataset[66]
axeslist.ravel()[0].imshow(x.detach().numpy(),cmap='gray')
axeslist.ravel()[1].imshow(y.detach().numpy(),cmap='gray')
print(x.shape)
z = model(x.view(1,101,101),d)
z = ((z>(1-threshold)) * (z<(1+threshold))).float()
axeslist.ravel()[2].imshow(z.squeeze(0).detach().numpy(),cmap='gray')
print(z.shape)
# def getImg(x):
#     x = x.view(1,3,101,101)
#     x = model(x).detach().squeeze(0).numpy()[0]
#     x = (x-x.mean()/(x.max()-x.min())) +1
#     a = np.expand_dims(x, axis = 2)
#     a = np.concatenate((a, a, a), axis = 2)
#     return a
# print(y.shape)
# predict = (F.sigmoid(z) > 0.5).detach().numpy().squeeze(0)
# axeslist.ravel()[3].imshow(predict,cmap='gray')


# # axeslist.ravel()[1].imshow(getImg(y),cmap='gray')

# axeslist.ravel()[2].imshow(y.detach().numpy(),cmap='gray')
plt.show()

# %%
|x = torch.randn(1,3,101,101)
plt.imshow(x.numpy().squeeze(0)[0])

# %%
torch.save(model,'TGSUNetsimple23.pt')
uploaded = drive.CreateFile({'title': 'TGSUNetsimple23.pt'})
uploaded.SetContentFile('TGSUNetsimple23.pt')
uploaded.Upload()

# %%
model = torch.load('TGSUNetsimple23.pt')

# %%
downloaded = drive.CreateFile({'id': '1Gs1AlcVL9WNlgHQPSpNvbFtSbqNFZIdu'})
downloaded.GetContentFile('test.zip')
with ZipFile("test.zip", 'r') as z:
  z.extractall()
os.remove("test.zip")

# %%
class TGSSaltTestDataset(Dataset):
    def __init__(self, image_dir,test_csv):
        self.image_dir=image_dir
#         self.filter = np.array([(0,-1,-1,-1),(1,0,0,0),(1,0,1,0),(0,1,0,1)])/8
        self.input = pd.read_csv(test_csv)
        
    def __len__(self):
        return len(self.input)

    def __getitem__(self, idx):
        img_name = os.path.join(self.image_dir,self.input.iloc[idx,0]+".png")
        img = cv2.imread(img_name)
        img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        
        img = torch.tensor(img).view(101,101).float()
#         depth = self.input.iloc[idx,1].reshape(1)
        
        return img,0

# %%
batch_size = 10
test_dataset = TGSSaltTestDataset("test/images","test.csv")
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size)

# %%
def predict(test_loader):
    threshold=0.3
    test_pred=torch.IntTensor().cuda()
    model.eval()
    for batch_idx,( data,d) in enumerate(test_loader):
        if torch.cuda.is_available():
            data = data.cuda()
#             target = target.cuda()
        # forward
        output = model(data,d)
        predictx = ((output>(1-threshold)) * (output<(1+threshold))).float().int()
        test_pred=torch.cat((test_pred,predictx.view(batch_size,101,101)),dim=0)
    return test_pred.cpu().numpy()

# %%
predict=prediciton(test_loader)
predict=predict.cpu().numpy()

# %%
def rle_encode(img):
    '''
    img: numpy array, 1 - mask, 0 - background
    Returns run length as string formated
    '''
    pixels = img.flatten()
    pixels = np.concatenate([[0], pixels, [0]])
    runs = np.where(pixels[1:] != pixels[:-1])[0] + 1
    runs[1::2] -= runs[::2]
    return ' '.join(str(x) for x in runs)

# %%
# test_dataset.input.drop("z",axis=1,inplace=True)
predicted = predict(test_loader)
test_dataset.input['rle_mask']=np.nan
for i in range(len(test_dataset)):
    test_dataset.input["rle_mask"][i]=rle_encode(predicted[i])

# %%
test_dataset.input.drop(["z"],axis=1,inplace=True)
test_dataset.input.to_csv("submission112.csv",index=False)
uploaded = drive.CreateFile({'title': 'submissions_near_thres1.csv'})
uploaded.SetContentFile('submission112.csv')
uploaded.Upload()

# %% [markdown]
# from https://github.com/milesial/Pytorch-UNet/blob/master/unet/unet_model.py

# %%
torch.__version__

# %%
test_dataset[6]

# %%
model=None
criterion=None

# %%
test_dataset.input.columns

# %%
model.cuda()

# %%
torch.tensor(2.0,requires_grad=True)
# Out:
# tensor(2., requires_grad=True)
